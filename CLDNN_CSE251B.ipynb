# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
import os.path

import scipy,scipy.spatial
import matplotlib
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/ucsd-cse-251b-class-competition.zip ./drive/MyDrive/CSE251B/

# %%
drive.flush_and_unmount()

# %%
# !cp ./weights.w ./drive/MyDrive/CSE251B/

# %%
# !cp ./drive/MyDrive/CSE251B/ucsd-cse-251b-class-competition.zip ./
# !unzip ucsd-cse-251b-class-competition.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/train/98379.pkl
#   inflating: train/train/9838.pkl
#   inflating: train/train/98380.pkl
#   inflating: train/train/98381.pkl
#   inflating: train/train/98382.pkl
#   inflating: train/train/98383.pkl
#   inflating: train/train/98384.pkl
#   inflating: train/train/98385.pkl
#   inflating: train/train/98386.pkl
#   inflating: train/train/98387.pkl
#   inflating: train/train/98388.pkl
#   inflating: train/train/98389.pkl
#   inflating: train/train/9839.pkl
#   inflating: train/train/98390.pkl
#   inflating: train/train/98391.pkl
#   inflating: train/train/98392.pkl
#   inflating: train/train/98393.pkl
#   inflating: train/train/98394.pkl
#   inflating: train/train/98395.pkl
#   inflating: train/train/98396.pkl
#   inflating: train/train/98397.pkl
#   inflating: train/train/98398.pkl
#   inflating: train/train/98399.pkl
#   inflating: train/train/984.pkl
#   inflating: train/train/9840.pkl
#   inflating: train/train/98400.pkl
#   inflating: train/train/98401.pkl
#   inflating: train/train/98402.pkl
#   inflating: train/train/98403.pkl
#   inflating: train/train/98404.pkl
#   inflating: train/train/98405.pkl
#   inflating: train/train/98406.pkl
#   inflating: train/train/98407.pkl
#   inflating: train/train/98408.pkl
#   inflating: train/train/98409.pkl
#   inflating: train/train/9841.pkl
#   inflating: train/train/98410.pkl
#   inflating: train/train/98411.pkl
#   inflating: train/train/98412.pkl
#   inflating: train/train/98413.pkl
#   inflating: train/train/98414.pkl
#   inflating: train/train/98415.pkl
#   inflating: train/train/98416.pkl
#   inflating: train/train/98417.pkl
#   inflating: train/train/98418.pkl
#   inflating: train/train/98419.pkl
#   inflating: train/train/9842.pkl
#   inflating: train/train/98420.pkl
#   inflating: train/train/98421.pkl
#   inflating: train/train/98422.pkl
#   inflating: train/train/98423.pkl
#   inflating: train/train/98424.pkl
#   inflating: train/train/98425.pkl
#   inflating: train/train/98426.pkl
#   inflating: train/train/98427.pkl
#   inflating: train/train/98428.pkl
#   inflating: train/train/98429.pkl
#   inflating: train/train/9843.pkl
#   inflating: train/train/98430.pkl
#   inflating: train/train/98431.pkl
#   inflating: train/train/98432.pkl
#   inflating: train/train/98433.pkl
#   inflating: train/train/98434.pkl
#   inflating: train/train/98435.pkl
#   inflating: train/train/98436.pkl
#   inflating: train/train/98437.pkl
#   inflating: train/train/98438.pkl
#   inflating: train/train/98439.pkl
#   inflating: train/train/9844.pkl
#   inflating: train/train/98440.pkl
#   inflating: train/train/98441.pkl
#   inflating: train/train/98442.pkl
#   inflating: train/train/98443.pkl
#   inflating: train/train/98444.pkl
#   inflating: train/train/98445.pkl
#   inflating: train/train/98446.pkl
#   inflating: train/train/98447.pkl
#   inflating: train/train/98448.pkl
#   inflating: train/train/98449.pkl
#   inflating: train/train/9845.pkl
#   inflating: train/train/98450.pkl
#   inflating: train/train/98451.pkl
#   inflating: train/train/98452.pkl
#   inflating: train/train/98453.pkl
#   inflating: train/train/98454.pkl
#   inflating: train/train/98455.pkl
#   inflating: train/train/98456.pkl
#   inflating: train/train/98457.pkl
#   inflating: train/train/98458.pkl
#   inflating: train/train/98459.pkl
#   inflating: train/train/9846.pkl
#   inflating: train/train/98460.pkl
#   inflating: train/train/98461.pkl
#   inflating: train/train/98462.pkl
#   inflating: train/train/98463.pkl
#   inflating: train/train/98464.pkl
#   inflating: train/train/98465.pkl
#   inflating: train/train/98466.pkl
#   inflating: train/train/98467.pkl
#   inflating: train/train/98468.pkl
#   inflating: train/train/98469.pkl
#   inflating: train/train/9847.pkl
#   inflating: train/train/98470.pkl
#   inflating: train/train/98471.pkl
#   inflating: train/train/98472.pkl
#   inflating: train/train/98473.pkl
#   inflating: train/train/98474.pkl
#   inflating: train/train/98475.pkl
#   inflating: train/train/98476.pkl
#   inflating: train/train/98477.pkl
#   inflating: train/train/98478.pkl
#   inflating: train/train/98479.pkl
#   inflating: train/train/9848.pkl
#   inflating: train/train/98480.pkl
#   inflating: train/train/98481.pkl
#   inflating: train/train/98482.pkl
#   inflating: train/train/98483.pkl
#   inflating: train/train/98484.pkl
#   inflating: train/train/98485.pkl
#   inflating: train/train/98486.pkl
#   inflating: train/train/98487.pkl
#   inflating: train/train/98488.pkl
#   inflating: train/train/98489.pkl
#   inflating: train/train/9849.pkl
#   inflating: train/train/98490.pkl
#   inflating: train/train/98491.pkl
#   inflating: train/train/98492.pkl
#   inflating: train/train/98493.pkl
#   inflating: train/train/98494.pkl
#   inflating: train/train/98495.pkl
#   inflating: train/train/98496.pkl
#   inflating: train/train/98497.pkl
#   inflating: train/train/98498.pkl
#   inflating: train/train/98499.pkl
#   inflating: train/train/985.pkl
#   inflating: train/train/9850.pkl
#   inflating: train/train/98500.pkl
#   inflating: train/train/98501.pkl
#   inflating: train/train/98502.pkl
#   inflating: train/train/98503.pkl
#   inflating: train/train/98504.pkl
#   inflating: train/train/98505.pkl
#   inflating: train/train/98506.pkl
#   inflating: train/train/98507.pkl
#   inflating: train/train/98508.pkl
#   inflating: train/train/98509.pkl
#   inflating: train/train/9851.pkl
#   inflating: train/train/98510.pkl
#   inflating: train/train/98511.pkl
#   inflating: train/train/98512.pkl
#   inflating: train/train/98513.pkl
#   inflating: train/train/98514.pkl
#   inflating: train/train/98515.pkl
#   inflating: train/train/98516.pkl
#   inflating: train/train/98517.pkl
#   inflating: train/train/98518.pkl
#   inflating: train/train/98519.pkl
#   inflating: train/train/9852.pkl
#   inflating: train/train/98520.pkl
#   inflating: train/train/98521.pkl
#   inflating: train/train/98522.pkl
#   inflating: train/train/98523.pkl
#   inflating: train/train/98524.pkl
#   inflating: train/train/98525.pkl
#   inflating: train/train/98526.pkl
#   inflating: train/train/98527.pkl
#   inflating: train/train/98528.pkl
#   inflating: train/train/98529.pkl
#   inflating: train/train/9853.pkl
#   inflating: train/train/98530.pkl
#   inflating: train/train/98531.pkl
#   inflating: train/train/98532.pkl
#   inflating: train/train/98533.pkl
#   inflating: train/train/98534.pkl
#   inflating: train/train/98535.pkl
#   inflating: train/train/98536.pkl
#   inflating: train/train/98537.pkl
#   inflating: train/train/98538.pkl
#   inflating: train/train/98539.pkl
#   inflating: train/train/9854.pkl
#   inflating: train/train/98540.pkl
#   inflating: train/train/98541.pkl
#   inflating: train/train/98542.pkl
#   inflating: train/train/98543.pkl
#   inflating: train/train/98544.pkl
#   inflating: train/train/98545.pkl
#   inflating: train/train/98546.pkl
#   inflating: train/train/98547.pkl
#   inflating: train/train/98548.pkl
#   inflating: train/train/98549.pkl
#   inflating: train/train/9855.pkl
#   inflating: train/train/98550.pkl
#   inflating: train/train/98551.pkl
#   inflating: train/train/98552.pkl
#   inflating: train/train/98553.pkl
#   inflating: train/train/98554.pkl
#   inflating: train/train/98555.pkl
#   inflating: train/train/98556.pkl
#   inflating: train/train/98557.pkl
#   inflating: train/train/98558.pkl
#   inflating: train/train/98559.pkl
#   inflating: train/train/9856.pkl
#   inflating: train/train/98560.pkl
#   inflating: train/train/98561.pkl
#   inflating: train/train/98562.pkl
#   inflating: train/train/98563.pkl
#   inflating: train/train/98564.pkl
#   inflating: train/train/98565.pkl
#   inflating: train/train/98566.pkl
#   inflating: train/train/98567.pkl
#   inflating: train/train/98568.pkl
#   inflating: train/train/98569.pkl
#   inflating: train/train/9857.pkl
#   inflating: train/train/98570.pkl
#   inflating: train/train/98571.pkl
#   inflating: train/train/98572.pkl
#   inflating: train/train/98573.pkl
#   inflating: train/train/98574.pkl
#   inflating: train/train/98575.pkl
#   inflating: train/train/98576.pkl
#   inflating: train/train/98577.pkl
#   inflating: train/train/98578.pkl
#   inflating: train/train/98579.pkl
#   inflating: train/train/9858.pkl
#   inflating: train/train/98580.pkl
#   inflating: train/train/98581.pkl
#   inflating: train/train/98582.pkl
#   inflating: train/train/98583.pkl
#   inflating: train/train/98584.pkl
#   inflating: train/train/98585.pkl
#   inflating: train/train/98586.pkl
#   inflating: train/train/98587.pkl
#   inflating: train/train/98588.pkl
#   inflating: train/train/98589.pkl
#   inflating: train/train/9859.pkl
#   inflating: train/train/98590.pkl
#   inflating: train/train/98591.pkl
#   inflating: train/train/98592.pkl
#   inflating: train/train/98593.pkl
#   inflating: train/train/98594.pkl
#   inflating: train/train/98595.pkl
#   inflating: train/train/98596.pkl
#   inflating: train/train/98597.pkl
#   inflating: train/train/98598.pkl
#   inflating: train/train/98599.pkl
#   inflating: train/train/986.pkl
#   inflating: train/train/9860.pkl
#   inflating: train/train/98600.pkl
#   inflating: train/train/98601.pkl
#   inflating: train/train/98602.pkl
#   inflating: train/train/98603.pkl
#   inflating: train/train/98604.pkl
#   inflating: train/train/98605.pkl
#   inflating: train/train/98606.pkl
#   inflating: train/train/98607.pkl
#   inflating: train/train/98608.pkl
#   inflating: train/train/98609.pkl
#   inflating: train/train/9861.pkl
#   inflating: train/train/98610.pkl
#   inflating: train/train/98611.pkl
#   inflating: train/train/98612.pkl
#   inflating: train/train/98613.pkl
#   inflating: train/train/98614.pkl
#   inflating: train/train/98615.pkl
#   inflating: train/train/98616.pkl
#   inflating: train/train/98617.pkl
#   inflating: train/train/98618.pkl
#   inflating: train/train/98619.pkl
#   inflating: train/train/9862.pkl
#   inflating: train/train/98620.pkl
#   inflating: train/train/98621.pkl
#   inflating: train/train/98622.pkl
#   inflating: train/train/98623.pkl
#   inflating: train/train/98624.pkl
#   inflating: train/train/98625.pkl
#   inflating: train/train/98626.pkl
#   inflating: train/train/98627.pkl
#   inflating: train/train/98628.pkl
#   inflating: train/train/98629.pkl
#   inflating: train/train/9863.pkl
#   inflating: train/train/98630.pkl
#   inflating: train/train/98631.pkl
#   inflating: train/train/98632.pkl
#   inflating: train/train/98633.pkl
#   inflating: train/train/98634.pkl
#   inflating: train/train/98635.pkl
#   inflating: train/train/98636.pkl
#   inflating: train/train/98637.pkl
#   inflating: train/train/98638.pkl
#   inflating: train/train/98639.pkl
#   inflating: train/train/9864.pkl
#   inflating: train/train/98640.pkl
#   inflating: train/train/98641.pkl
#   inflating: train/train/98642.pkl
#   inflating: train/train/98643.pkl
#   inflating: train/train/98644.pkl
#   inflating: train/train/98645.pkl
#   inflating: train/train/98646.pkl
#   inflating: train/train/98647.pkl
#   inflating: train/train/98648.pkl
#   inflating: train/train/98649.pkl
#   inflating: train/train/9865.pkl
#   inflating: train/train/98650.pkl
#   inflating: train/train/98651.pkl
#   inflating: train/train/98652.pkl
#   inflating: train/train/98653.pkl
#   inflating: train/train/98654.pkl
#   inflating: train/train/98655.pkl
#   inflating: train/train/98656.pkl
#   inflating: train/train/98657.pkl
#   inflating: train/train/98658.pkl
#   inflating: train/train/98659.pkl
#   inflating: train/train/9866.pkl
#   inflating: train/train/98660.pkl
#   inflating: train/train/98661.pkl
#   inflating: train/train/98662.pkl
#   inflating: train/train/98663.pkl
#   inflating: train/train/98664.pkl
#   inflating: train/train/98665.pkl
#   inflating: train/train/98666.pkl
#   inflating: train/train/98667.pkl
#   inflating: train/train/98668.pkl
#   inflating: train/train/98669.pkl
#   inflating: train/train/9867.pkl
#   inflating: train/train/98670.pkl
#   inflating: train/train/98671.pkl
#   inflating: train/train/98672.pkl
#   inflating: train/train/98673.pkl
#   inflating: train/train/98674.pkl
#   inflating: train/train/98675.pkl
#   inflating: train/train/98676.pkl
#   inflating: train/train/98677.pkl
#   inflating: train/train/98678.pkl
#   inflating: train/train/98679.pkl
#   inflating: train/train/9868.pkl
#   inflating: train/train/98680.pkl
#   inflating: train/train/98681.pkl
#   inflating: train/train/98682.pkl
#   inflating: train/train/98683.pkl
#   inflating: train/train/98684.pkl
#   inflating: train/train/98685.pkl
#   inflating: train/train/98686.pkl
#   inflating: train/train/98687.pkl
#   inflating: train/train/98688.pkl
#   inflating: train/train/98689.pkl
#   inflating: train/train/9869.pkl
#   inflating: train/train/98690.pkl
#   inflating: train/train/98691.pkl
#   inflating: train/train/98692.pkl
#   inflating: train/train/98693.pkl
#   inflating: train/train/98694.pkl
#   inflating: train/train/98695.pkl
#   inflating: train/train/98696.pkl
#   inflating: train/train/98697.pkl
#   inflating: train/train/98698.pkl
#   inflating: train/train/98699.pkl
#   inflating: train/train/987.pkl
#   inflating: train/train/9870.pkl
#   inflating: train/train/98700.pkl
#   inflating: train/train/98701.pkl
#   inflating: train/train/98702.pkl
#   inflating: train/train/98703.pkl
#   inflating: train/train/98704.pkl
#   inflating: train/train/98705.pkl
#   inflating: train/train/98706.pkl
#   inflating: train/train/98707.pkl
#   inflating: train/train/98708.pkl
#   inflating: train/train/98709.pkl
#   inflating: train/train/9871.pkl
#   inflating: train/train/98710.pkl
#   inflating: train/train/98711.pkl
#   inflating: train/train/98712.pkl
#   inflating: train/train/98713.pkl
#   inflating: train/train/98714.pkl
#   inflating: train/train/98715.pkl
#   inflating: train/train/98716.pkl
#   inflating: train/train/98717.pkl
#   inflating: train/train/98718.pkl
#   inflating: train/train/98719.pkl
#   inflating: train/train/9872.pkl
#   inflating: train/train/98720.pkl
#   inflating: train/train/98721.pkl
#   inflating: train/train/98722.pkl
#   inflating: train/train/98723.pkl
#   inflating: train/train/98724.pkl
#   inflating: train/train/98725.pkl
#   inflating: train/train/98726.pkl
#   inflating: train/train/98727.pkl
#   inflating: train/train/98728.pkl
#   inflating: train/train/98729.pkl
#   inflating: train/train/9873.pkl
#   inflating: train/train/98730.pkl
#   inflating: train/train/98731.pkl
#   inflating: train/train/98732.pkl
#   inflating: train/train/98733.pkl
#   inflating: train/train/98734.pkl
#   inflating: train/train/98735.pkl
#   inflating: train/train/98736.pkl
#   inflating: train/train/98737.pkl
#   inflating: train/train/98738.pkl
#   inflating: train/train/98739.pkl
#   inflating: train/train/9874.pkl
#   inflating: train/train/98740.pkl
#   inflating: train/train/98741.pkl
#   inflating: train/train/98742.pkl
#   inflating: train/train/98743.pkl
#   inflating: train/train/98744.pkl
#   inflating: train/train/98745.pkl
#   inflating: train/train/98746.pkl
#   inflating: train/train/98747.pkl
#   inflating: train/train/98748.pkl
#   inflating: train/train/98749.pkl
#   inflating: train/train/9875.pkl
#   inflating: train/train/98750.pkl
#   inflating: train/train/98751.pkl
#   inflating: train/train/98752.pkl
#   inflating: train/train/98753.pkl
#   inflating: train/train/98754.pkl
#   inflating: train/train/98755.pkl
#   inflating: train/train/98756.pkl
#   inflating: train/train/98757.pkl
#   inflating: train/train/98758.pkl
#   inflating: train/train/98759.pkl
#   inflating: train/train/9876.pkl
#   inflating: train/train/98760.pkl
#   inflating: train/train/98761.pkl
#   inflating: train/train/98762.pkl
#   inflating: train/train/98763.pkl
#   inflating: train/train/98764.pkl
#   inflating: train/train/98765.pkl
#   inflating: train/train/98766.pkl
#   inflating: train/train/98767.pkl
#   inflating: train/train/98768.pkl
#   inflating: train/train/98769.pkl
#   inflating: train/train/9877.pkl
#   inflating: train/train/98770.pkl
#   inflating: train/train/98771.pkl
#   inflating: train/train/98772.pkl
#   inflating: train/train/98773.pkl
#   inflating: train/train/98774.pkl
#   inflating: train/train/98775.pkl
#   inflating: train/train/98776.pkl
#   inflating: train/train/98777.pkl
#   inflating: train/train/98778.pkl
#   inflating: train/train/98779.pkl
#   inflating: train/train/9878.pkl
#   inflating: train/train/98780.pkl
#   inflating: train/train/98781.pkl
#   inflating: train/train/98782.pkl
#   inflating: train/train/98783.pkl
#   inflating: train/train/98784.pkl
#   inflating: train/train/98785.pkl
#   inflating: train/train/98786.pkl
#   inflating: train/train/98787.pkl
#   inflating: train/train/98788.pkl
#   inflating: train/train/98789.pkl
#   inflating: train/train/9879.pkl
#   inflating: train/train/98790.pkl
#   inflating: train/train/98791.pkl
#   inflating: train/train/98792.pkl
#   inflating: train/train/98793.pkl
#   inflating: train/train/98794.pkl
#   inflating: train/train/98795.pkl
#   inflating: train/train/98796.pkl
#   inflating: train/train/98797.pkl
#   inflating: train/train/98798.pkl
#   inflating: train/train/98799.pkl
#   inflating: train/train/988.pkl
#   inflating: train/train/9880.pkl
#   inflating: train/train/98800.pkl
#   inflating: train/train/98801.pkl
#   inflating: train/train/98802.pkl
#   inflating: train/train/98803.pkl
#   inflating: train/train/98804.pkl
#   inflating: train/train/98805.pkl
#   inflating: train/train/98806.pkl
#   inflating: train/train/98807.pkl
#   inflating: train/train/98808.pkl
#   inflating: train/train/98809.pkl
#   inflating: train/train/9881.pkl
#   inflating: train/train/98810.pkl
#   inflating: train/train/98811.pkl
#   inflating: train/train/98812.pkl
#   inflating: train/train/98813.pkl
#   inflating: train/train/98814.pkl
#   inflating: train/train/98815.pkl
#   inflating: train/train/98816.pkl
#   inflating: train/train/98817.pkl
#   inflating: train/train/98818.pkl
#   inflating: train/train/98819.pkl
#   inflating: train/train/9882.pkl
#   inflating: train/train/98820.pkl
#   inflating: train/train/98821.pkl
#   inflating: train/train/98822.pkl
#   inflating: train/train/98823.pkl
#   inflating: train/train/98824.pkl
#   inflating: train/train/98825.pkl
#   inflating: train/train/98826.pkl
#   inflating: train/train/98827.pkl
#   inflating: train/train/98828.pkl
#   inflating: train/train/98829.pkl
#   inflating: train/train/9883.pkl
#   inflating: train/train/98830.pkl
#   inflating: train/train/98831.pkl
#   inflating: train/train/98832.pkl
#   inflating: train/train/98833.pkl
#   inflating: train/train/98834.pkl
#   inflating: train/train/98835.pkl
#   inflating: train/train/98836.pkl
#   inflating: train/train/98837.pkl
#   inflating: train/train/98838.pkl
#   inflating: train/train/98839.pkl
#   inflating: train/train/9884.pkl
#   inflating: train/train/98840.pkl
#   inflating: train/train/98841.pkl
#   inflating: train/train/98842.pkl
#   inflating: train/train/98843.pkl
#   inflating: train/train/98844.pkl
#   inflating: train/train/98845.pkl
#   inflating: train/train/98846.pkl
#   inflating: train/train/98847.pkl
#   inflating: train/train/98848.pkl
#   inflating: train/train/98849.pkl
#   inflating: train/train/9885.pkl
#   inflating: train/train/98850.pkl
#   inflating: train/train/98851.pkl
#   inflating: train/train/98852.pkl
#   inflating: train/train/98853.pkl
#   inflating: train/train/98854.pkl
#   inflating: train/train/98855.pkl
#   inflating: train/train/98856.pkl
#   inflating: train/train/98857.pkl
#   inflating: train/train/98858.pkl
#   inflating: train/train/98859.pkl
#   inflating: train/train/9886.pkl
#   inflating: train/train/98860.pkl
#   inflating: train/train/98861.pkl
#   inflating: train/train/98862.pkl
#   inflating: train/train/98863.pkl
#   inflating: train/train/98864.pkl
#   inflating: train/train/98865.pkl
#   inflating: train/train/98866.pkl
#   inflating: train/train/98867.pkl
#   inflating: train/train/98868.pkl
#   inflating: train/train/98869.pkl
#   inflating: train/train/9887.pkl
#   inflating: train/train/98870.pkl
#   inflating: train/train/98871.pkl
#   inflating: train/train/98872.pkl
#   inflating: train/train/98873.pkl
#   inflating: train/train/98874.pkl
#   inflating: train/train/98875.pkl
#   inflating: train/train/98876.pkl
#   inflating: train/train/98877.pkl
#   inflating: train/train/98878.pkl
#   inflating: train/train/98879.pkl
#   inflating: train/train/9888.pkl
#   inflating: train/train/98880.pkl
#   inflating: train/train/98881.pkl
#   inflating: train/train/98882.pkl
#   inflating: train/train/98883.pkl
#   inflating: train/train/98884.pkl
#   inflating: train/train/98885.pkl
#   inflating: train/train/98886.pkl
#   inflating: train/train/98887.pkl
#   inflating: train/train/98888.pkl
#   inflating: train/train/98889.pkl
#   inflating: train/train/9889.pkl
#   inflating: train/train/98890.pkl
#   inflating: train/train/98891.pkl
#   inflating: train/train/98892.pkl
#   inflating: train/train/98893.pkl
#   inflating: train/train/98894.pkl
#   inflating: train/train/98895.pkl
#   inflating: train/train/98896.pkl
#   inflating: train/train/98897.pkl
#   inflating: train/train/98898.pkl
#   inflating: train/train/98899.pkl
#   inflating: train/train/989.pkl
#   inflating: train/train/9890.pkl
#   inflating: train/train/98900.pkl
#   inflating: train/train/98901.pkl
#   inflating: train/train/98902.pkl
#   inflating: train/train/98903.pkl
#   inflating: train/train/98904.pkl
#   inflating: train/train/98905.pkl
#   inflating: train/train/98906.pkl
#   inflating: train/train/98907.pkl
#   inflating: train/train/98908.pkl
#   inflating: train/train/98909.pkl
#   inflating: train/train/9891.pkl
#   inflating: train/train/98910.pkl
#   inflating: train/train/98911.pkl
#   inflating: train/train/98912.pkl
#   inflating: train/train/98913.pkl
#   inflating: train/train/98914.pkl
#   inflating: train/train/98915.pkl
#   inflating: train/train/98916.pkl
#   inflating: train/train/98917.pkl
#   inflating: train/train/98918.pkl
#   inflating: train/train/98919.pkl
#   inflating: train/train/9892.pkl
#   inflating: train/train/98920.pkl
#   inflating: train/train/98921.pkl
#   inflating: train/train/98922.pkl
#   inflating: train/train/98923.pkl
#   inflating: train/train/98924.pkl
#   inflating: train/train/98925.pkl
#   inflating: train/train/98926.pkl
#   inflating: train/train/98927.pkl
#   inflating: train/train/98928.pkl
#   inflating: train/train/98929.pkl
#   inflating: train/train/9893.pkl
#   inflating: train/train/98930.pkl
#   inflating: train/train/98931.pkl
#   inflating: train/train/98932.pkl
#   inflating: train/train/98933.pkl
#   inflating: train/train/98934.pkl
#   inflating: train/train/98935.pkl
#   inflating: train/train/98936.pkl
#   inflating: train/train/98937.pkl
#   inflating: train/train/98938.pkl
#   inflating: train/train/98939.pkl
#   inflating: train/train/9894.pkl
#   inflating: train/train/98940.pkl
#   inflating: train/train/98941.pkl
#   inflating: train/train/98942.pkl
#   inflating: train/train/98943.pkl
#   inflating: train/train/98944.pkl
#   inflating: train/train/98945.pkl
#   inflating: train/train/98946.pkl
#   inflating: train/train/98947.pkl
#   inflating: train/train/98948.pkl
#   inflating: train/train/98949.pkl
#   inflating: train/train/9895.pkl
#   inflating: train/train/98950.pkl
#   inflating: train/train/98951.pkl
#   inflating: train/train/98952.pkl
#   inflating: train/train/98953.pkl
#   inflating: train/train/98954.pkl
#   inflating: train/train/98955.pkl
#   inflating: train/train/98956.pkl
#   inflating: train/train/98957.pkl
#   inflating: train/train/98958.pkl
#   inflating: train/train/98959.pkl
#   inflating: train/train/9896.pkl
#   inflating: train/train/98960.pkl
#   inflating: train/train/98961.pkl
#   inflating: train/train/98962.pkl
#   inflating: train/train/98963.pkl
#   inflating: train/train/98964.pkl
#   inflating: train/train/98965.pkl
#   inflating: train/train/98966.pkl
#   inflating: train/train/98967.pkl
#   inflating: train/train/98968.pkl
#   inflating: train/train/98969.pkl
#   inflating: train/train/9897.pkl
#   inflating: train/train/98970.pkl
#   inflating: train/train/98971.pkl
#   inflating: train/train/98972.pkl
#   inflating: train/train/98973.pkl
#   inflating: train/train/98974.pkl
#   inflating: train/train/98975.pkl
#   inflating: train/train/98976.pkl
#   inflating: train/train/98977.pkl
#   inflating: train/train/98978.pkl
#   inflating: train/train/98979.pkl
#   inflating: train/train/9898.pkl
#   inflating: train/train/98980.pkl
#   inflating: train/train/98981.pkl
#   inflating: train/train/98982.pkl
#   inflating: train/train/98983.pkl
#   inflating: train/train/98984.pkl
#   inflating: train/train/98985.pkl
#   inflating: train/train/98986.pkl
#   inflating: train/train/98987.pkl
#   inflating: train/train/98988.pkl
#   inflating: train/train/98989.pkl
#   inflating: train/train/9899.pkl
#   inflating: train/train/98990.pkl
#   inflating: train/train/98991.pkl
#   inflating: train/train/98992.pkl
#   inflating: train/train/98993.pkl
#   inflating: train/train/98994.pkl
#   inflating: train/train/98995.pkl
#   inflating: train/train/98996.pkl
#   inflating: train/train/98997.pkl
#   inflating: train/train/98998.pkl
#   inflating: train/train/98999.pkl
#   inflating: train/train/99.pkl
#   inflating: train/train/990.pkl
#   inflating: train/train/9900.pkl
#   inflating: train/train/99000.pkl
#   inflating: train/train/99001.pkl
#   inflating: train/train/99002.pkl
#   inflating: train/train/99003.pkl
#   inflating: train/train/99004.pkl
#   inflating: train/train/99005.pkl
#   inflating: train/train/99006.pkl
#   inflating: train/train/99007.pkl
#   inflating: train/train/99008.pkl
#   inflating: train/train/99009.pkl
#   inflating: train/train/9901.pkl
#   inflating: train/train/99010.pkl
#   inflating: train/train/99011.pkl
#   inflating: train/train/99012.pkl
#   inflating: train/train/99013.pkl
#   inflating: train/train/99014.pkl
#   inflating: train/train/99015.pkl
#   inflating: train/train/99016.pkl
#   inflating: train/train/99017.pkl
#   inflating: train/train/99018.pkl
#   inflating: train/train/99019.pkl
#   inflating: train/train/9902.pkl
#   inflating: train/train/99020.pkl
#   inflating: train/train/99021.pkl
#   inflating: train/train/99022.pkl
#   inflating: train/train/99023.pkl
#   inflating: train/train/99024.pkl
#   inflating: train/train/99025.pkl
#   inflating: train/train/99026.pkl
#   inflating: train/train/99027.pkl
#   inflating: train/train/99028.pkl
#   inflating: train/train/99029.pkl
#   inflating: train/train/9903.pkl
#   inflating: train/train/99030.pkl
#   inflating: train/train/99031.pkl
#   inflating: train/train/99032.pkl
#   inflating: train/train/99033.pkl
#   inflating: train/train/99034.pkl
#   inflating: train/train/99035.pkl
#   inflating: train/train/99036.pkl
#   inflating: train/train/99037.pkl
#   inflating: train/train/99038.pkl
#   inflating: train/train/99039.pkl
#   inflating: train/train/9904.pkl
#   inflating: train/train/99040.pkl
#   inflating: train/train/99041.pkl
#   inflating: train/train/99042.pkl
#   inflating: train/train/99043.pkl
#   inflating: train/train/99044.pkl
#   inflating: train/train/99045.pkl
#   inflating: train/train/99046.pkl
#   inflating: train/train/99047.pkl
#   inflating: train/train/99048.pkl
#   inflating: train/train/99049.pkl
#   inflating: train/train/9905.pkl
#   inflating: train/train/99050.pkl
#   inflating: train/train/99051.pkl
#   inflating: train/train/99052.pkl
#   inflating: train/train/99053.pkl
#   inflating: train/train/99054.pkl
#   inflating: train/train/99055.pkl
#   inflating: train/train/99056.pkl
#   inflating: train/train/99057.pkl
#   inflating: train/train/99058.pkl
#   inflating: train/train/99059.pkl
#   inflating: train/train/9906.pkl
#   inflating: train/train/99060.pkl
#   inflating: train/train/99061.pkl
#   inflating: train/train/99062.pkl
#   inflating: train/train/99063.pkl
#   inflating: train/train/99064.pkl
#   inflating: train/train/99065.pkl
#   inflating: train/train/99066.pkl
#   inflating: train/train/99067.pkl
#   inflating: train/train/99068.pkl
#   inflating: train/train/99069.pkl
#   inflating: train/train/9907.pkl
#   inflating: train/train/99070.pkl
#   inflating: train/train/99071.pkl
#   inflating: train/train/99072.pkl
#   inflating: train/train/99073.pkl
#   inflating: train/train/99074.pkl
#   inflating: train/train/99075.pkl
#   inflating: train/train/99076.pkl
#   inflating: train/train/99077.pkl
#   inflating: train/train/99078.pkl
#   inflating: train/train/99079.pkl
#   inflating: train/train/9908.pkl
#   inflating: train/train/99080.pkl
#   inflating: train/train/99081.pkl
#   inflating: train/train/99082.pkl
#   inflating: train/train/99083.pkl
#   inflating: train/train/99084.pkl
#   inflating: train/train/99085.pkl
#   inflating: train/train/99086.pkl
#   inflating: train/train/99087.pkl
#   inflating: train/train/99088.pkl
#   inflating: train/train/99089.pkl
#   inflating: train/train/9909.pkl
#   inflating: train/train/99090.pkl
#   inflating: train/train/99091.pkl
#   inflating: train/train/99092.pkl
#   inflating: train/train/99093.pkl
#   inflating: train/train/99094.pkl
#   inflating: train/train/99095.pkl
#   inflating: train/train/99096.pkl
#   inflating: train/train/99097.pkl
#   inflating: train/train/99098.pkl
#   inflating: train/train/99099.pkl
#   inflating: train/train/991.pkl
#   inflating: train/train/9910.pkl
#   inflating: train/train/99100.pkl
#   inflating: train/train/99101.pkl
#   inflating: train/train/99102.pkl
#   inflating: train/train/99103.pkl
#   inflating: train/train/99104.pkl
#   inflating: train/train/99105.pkl
#   inflating: train/train/99106.pkl
#   inflating: train/train/99107.pkl
#   inflating: train/train/99108.pkl
#   inflating: train/train/99109.pkl
#   inflating: train/train/9911.pkl
#   inflating: train/train/99110.pkl
#   inflating: train/train/99111.pkl
#   inflating: train/train/99112.pkl
#   inflating: train/train/99113.pkl
#   inflating: train/train/99114.pkl
#   inflating: train/train/99115.pkl
#   inflating: train/train/99116.pkl
#   inflating: train/train/99117.pkl
#   inflating: train/train/99118.pkl
#   inflating: train/train/99119.pkl
#   inflating: train/train/9912.pkl
#   inflating: train/train/99120.pkl
#   inflating: train/train/99121.pkl
#   inflating: train/train/99122.pkl
#   inflating: train/train/99123.pkl
#   inflating: train/train/99124.pkl
#   inflating: train/train/99125.pkl
#   inflating: train/train/99126.pkl
#   inflating: train/train/99127.pkl
#   inflating: train/train/99128.pkl
#   inflating: train/train/99129.pkl
#   inflating: train/train/9913.pkl
#   inflating: train/train/99130.pkl
#   inflating: train/train/99131.pkl
#   inflating: train/train/99132.pkl
#   inflating: train/train/99133.pkl
#   inflating: train/train/99134.pkl
#   inflating: train/train/99135.pkl
#   inflating: train/train/99136.pkl
#   inflating: train/train/99137.pkl
#   inflating: train/train/99138.pkl
#   inflating: train/train/99139.pkl
#   inflating: train/train/9914.pkl
#   inflating: train/train/99140.pkl
#   inflating: train/train/99141.pkl
#   inflating: train/train/99142.pkl
#   inflating: train/train/99143.pkl
#   inflating: train/train/99144.pkl
#   inflating: train/train/99145.pkl
#   inflating: train/train/99146.pkl
#   inflating: train/train/99147.pkl
#   inflating: train/train/99148.pkl
#   inflating: train/train/99149.pkl
#   inflating: train/train/9915.pkl
#   inflating: train/train/99150.pkl
#   inflating: train/train/99151.pkl
#   inflating: train/train/99152.pkl
#   inflating: train/train/99153.pkl
#   inflating: train/train/99154.pkl
#   inflating: train/train/99155.pkl
#   inflating: train/train/99156.pkl
#   inflating: train/train/99157.pkl
#   inflating: train/train/99158.pkl
#   inflating: train/train/99159.pkl
#   inflating: train/train/9916.pkl
#   inflating: train/train/99160.pkl
#   inflating: train/train/99161.pkl
#   inflating: train/train/99162.pkl
#   inflating: train/train/99163.pkl
#   inflating: train/train/99164.pkl
#   inflating: train/train/99165.pkl
#   inflating: train/train/99166.pkl
#   inflating: train/train/99167.pkl
#   inflating: train/train/99168.pkl
#   inflating: train/train/99169.pkl
#   inflating: train/train/9917.pkl
#   inflating: train/train/99170.pkl
#   inflating: train/train/99171.pkl
#   inflating: train/train/99172.pkl
#   inflating: train/train/99173.pkl
#   inflating: train/train/99174.pkl
#   inflating: train/train/99175.pkl
#   inflating: train/train/99176.pkl
#   inflating: train/train/99177.pkl
#   inflating: train/train/99178.pkl
#   inflating: train/train/99179.pkl
#   inflating: train/train/9918.pkl
#   inflating: train/train/99180.pkl
#   inflating: train/train/99181.pkl
#   inflating: train/train/99182.pkl
#   inflating: train/train/99183.pkl
#   inflating: train/train/99184.pkl
#   inflating: train/train/99185.pkl
#   inflating: train/train/99186.pkl
#   inflating: train/train/99187.pkl
#   inflating: train/train/99188.pkl
#   inflating: train/train/99189.pkl
#   inflating: train/train/9919.pkl
#   inflating: train/train/99190.pkl
#   inflating: train/train/99191.pkl
#   inflating: train/train/99192.pkl
#   inflating: train/train/99193.pkl
#   inflating: train/train/99194.pkl
#   inflating: train/train/99195.pkl
#   inflating: train/train/99196.pkl
#   inflating: train/train/99197.pkl
#   inflating: train/train/99198.pkl
#   inflating: train/train/99199.pkl
#   inflating: train/train/992.pkl
#   inflating: train/train/9920.pkl
#   inflating: train/train/99200.pkl
#   inflating: train/train/99201.pkl
#   inflating: train/train/99202.pkl
#   inflating: train/train/99203.pkl
#   inflating: train/train/99204.pkl
#   inflating: train/train/99205.pkl
#   inflating: train/train/99206.pkl
#   inflating: train/train/99207.pkl
#   inflating: train/train/99208.pkl
#   inflating: train/train/99209.pkl
#   inflating: train/train/9921.pkl
#   inflating: train/train/99210.pkl
#   inflating: train/train/99211.pkl
#   inflating: train/train/99212.pkl
#   inflating: train/train/99213.pkl
#   inflating: train/train/99214.pkl
#   inflating: train/train/99215.pkl
#   inflating: train/train/99216.pkl
#   inflating: train/train/99217.pkl
#   inflating: train/train/99218.pkl
#   inflating: train/train/99219.pkl
#   inflating: train/train/9922.pkl
#   inflating: train/train/99220.pkl
#   inflating: train/train/99221.pkl
#   inflating: train/train/99222.pkl
#   inflating: train/train/99223.pkl
#   inflating: train/train/99224.pkl
#   inflating: train/train/99225.pkl
#   inflating: train/train/99226.pkl
#   inflating: train/train/99227.pkl
#   inflating: train/train/99228.pkl
#   inflating: train/train/99229.pkl
#   inflating: train/train/9923.pkl
#   inflating: train/train/99230.pkl
#   inflating: train/train/99231.pkl
#   inflating: train/train/99232.pkl
#   inflating: train/train/99233.pkl
#   inflating: train/train/99234.pkl
#   inflating: train/train/99235.pkl
#   inflating: train/train/99236.pkl
#   inflating: train/train/99237.pkl
#   inflating: train/train/99238.pkl
#   inflating: train/train/99239.pkl
#   inflating: train/train/9924.pkl
#   inflating: train/train/99240.pkl
#   inflating: train/train/99241.pkl
#   inflating: train/train/99242.pkl
#   inflating: train/train/99243.pkl
#   inflating: train/train/99244.pkl
#   inflating: train/train/99245.pkl
#   inflating: train/train/99246.pkl
#   inflating: train/train/99247.pkl
#   inflating: train/train/99248.pkl
#   inflating: train/train/99249.pkl
#   inflating: train/train/9925.pkl
#   inflating: train/train/99250.pkl
#   inflating: train/train/99251.pkl
#   inflating: train/train/99252.pkl
#   inflating: train/train/99253.pkl
#   inflating: train/train/99254.pkl
#   inflating: train/train/99255.pkl
#   inflating: train/train/99256.pkl
#   inflating: train/train/99257.pkl
#   inflating: train/train/99258.pkl
#   inflating: train/train/99259.pkl
#   inflating: train/train/9926.pkl
#   inflating: train/train/99260.pkl
#   inflating: train/train/99261.pkl
#   inflating: train/train/99262.pkl
#   inflating: train/train/99263.pkl
#   inflating: train/train/99264.pkl
#   inflating: train/train/99265.pkl
#   inflating: train/train/99266.pkl
#   inflating: train/train/99267.pkl
#   inflating: train/train/99268.pkl
#   inflating: train/train/99269.pkl
#   inflating: train/train/9927.pkl
#   inflating: train/train/99270.pkl
#   inflating: train/train/99271.pkl
#   inflating: train/train/99272.pkl
#   inflating: train/train/99273.pkl
#   inflating: train/train/99274.pkl
#   inflating: train/train/99275.pkl
#   inflating: train/train/99276.pkl
#   inflating: train/train/99277.pkl
#   inflating: train/train/99278.pkl
#   inflating: train/train/99279.pkl
#   inflating: train/train/9928.pkl
#   inflating: train/train/99280.pkl
#   inflating: train/train/99281.pkl
#   inflating: train/train/99282.pkl
#   inflating: train/train/99283.pkl
#   inflating: train/train/99284.pkl
#   inflating: train/train/99285.pkl
#   inflating: train/train/99286.pkl
#   inflating: train/train/99287.pkl
#   inflating: train/train/99288.pkl
#   inflating: train/train/99289.pkl
#   inflating: train/train/9929.pkl
#   inflating: train/train/99290.pkl
#   inflating: train/train/99291.pkl
#   inflating: train/train/99292.pkl
#   inflating: train/train/99293.pkl
#   inflating: train/train/99294.pkl
#   inflating: train/train/99295.pkl
#   inflating: train/train/99296.pkl
#   inflating: train/train/99297.pkl
#   inflating: train/train/99298.pkl
#   inflating: train/train/99299.pkl
#   inflating: train/train/993.pkl
#   inflating: train/train/9930.pkl
#   inflating: train/train/99300.pkl
#   inflating: train/train/99301.pkl
#   inflating: train/train/99302.pkl
#   inflating: train/train/99303.pkl
#   inflating: train/train/99304.pkl
#   inflating: train/train/99305.pkl
#   inflating: train/train/99306.pkl
#   inflating: train/train/99307.pkl
#   inflating: train/train/99308.pkl
#   inflating: train/train/99309.pkl
#   inflating: train/train/9931.pkl
#   inflating: train/train/99310.pkl
#   inflating: train/train/99311.pkl
#   inflating: train/train/99312.pkl
#   inflating: train/train/99313.pkl
#   inflating: train/train/99314.pkl
#   inflating: train/train/99315.pkl
#   inflating: train/train/99316.pkl
#   inflating: train/train/99317.pkl
#   inflating: train/train/99318.pkl
#   inflating: train/train/99319.pkl
#   inflating: train/train/9932.pkl
#   inflating: train/train/99320.pkl
#   inflating: train/train/99321.pkl
#   inflating: train/train/99322.pkl
#   inflating: train/train/99323.pkl
#   inflating: train/train/99324.pkl
#   inflating: train/train/99325.pkl
#   inflating: train/train/99326.pkl
#   inflating: train/train/99327.pkl
#   inflating: train/train/99328.pkl
#   inflating: train/train/99329.pkl
#   inflating: train/train/9933.pkl
#   inflating: train/train/99330.pkl
#   inflating: train/train/99331.pkl
#   inflating: train/train/99332.pkl
#   inflating: train/train/99333.pkl
#   inflating: train/train/99334.pkl
#   inflating: train/train/99335.pkl
#   inflating: train/train/99336.pkl
#   inflating: train/train/99337.pkl
#   inflating: train/train/99338.pkl
#   inflating: train/train/99339.pkl
#   inflating: train/train/9934.pkl
#   inflating: train/train/99340.pkl
#   inflating: train/train/99341.pkl
#   inflating: train/train/99342.pkl
#   inflating: train/train/99343.pkl
#   inflating: train/train/99344.pkl
#   inflating: train/train/99345.pkl
#   inflating: train/train/99346.pkl
#   inflating: train/train/99347.pkl
#   inflating: train/train/99348.pkl
#   inflating: train/train/99349.pkl
#   inflating: train/train/9935.pkl
#   inflating: train/train/99350.pkl
#   inflating: train/train/99351.pkl
#   inflating: train/train/99352.pkl
#   inflating: train/train/99353.pkl
#   inflating: train/train/99354.pkl
#   inflating: train/train/99355.pkl
#   inflating: train/train/99356.pkl
#   inflating: train/train/99357.pkl
#   inflating: train/train/99358.pkl
#   inflating: train/train/99359.pkl
#   inflating: train/train/9936.pkl
#   inflating: train/train/99360.pkl
#   inflating: train/train/99361.pkl
#   inflating: train/train/99362.pkl
#   inflating: train/train/99363.pkl
#   inflating: train/train/99364.pkl
#   inflating: train/train/99365.pkl
#   inflating: train/train/99366.pkl
#   inflating: train/train/99367.pkl
#   inflating: train/train/99368.pkl
#   inflating: train/train/99369.pkl
#   inflating: train/train/9937.pkl
#   inflating: train/train/99370.pkl
#   inflating: train/train/99371.pkl
#   inflating: train/train/99372.pkl
#   inflating: train/train/99373.pkl
#   inflating: train/train/99374.pkl
#   inflating: train/train/99375.pkl
#   inflating: train/train/99376.pkl
#   inflating: train/train/99377.pkl
#   inflating: train/train/99378.pkl
#   inflating: train/train/99379.pkl
#   inflating: train/train/9938.pkl
#   inflating: train/train/99380.pkl
#   inflating: train/train/99381.pkl
#   inflating: train/train/99382.pkl
#   inflating: train/train/99383.pkl
#   inflating: train/train/99384.pkl
#   inflating: train/train/99385.pkl
#   inflating: train/train/99386.pkl
#   inflating: train/train/99387.pkl
#   inflating: train/train/99388.pkl
#   inflating: train/train/99389.pkl
#   inflating: train/train/9939.pkl
#   inflating: train/train/99390.pkl
#   inflating: train/train/99391.pkl
#   inflating: train/train/99392.pkl
#   inflating: train/train/99393.pkl
#   inflating: train/train/99394.pkl
#   inflating: train/train/99395.pkl
#   inflating: train/train/99396.pkl
#   inflating: train/train/99397.pkl
#   inflating: train/train/99398.pkl
#   inflating: train/train/99399.pkl
#   inflating: train/train/994.pkl
#   inflating: train/train/9940.pkl
#   inflating: train/train/99400.pkl
#   inflating: train/train/99401.pkl
#   inflating: train/train/99402.pkl
#   inflating: train/train/99403.pkl
#   inflating: train/train/99404.pkl
#   inflating: train/train/99405.pkl
#   inflating: train/train/99406.pkl
#   inflating: train/train/99407.pkl
#   inflating: train/train/99408.pkl
#   inflating: train/train/99409.pkl
#   inflating: train/train/9941.pkl
#   inflating: train/train/99410.pkl
#   inflating: train/train/99411.pkl
#   inflating: train/train/99412.pkl
#   inflating: train/train/99413.pkl
#   inflating: train/train/99414.pkl
#   inflating: train/train/99415.pkl
#   inflating: train/train/99416.pkl
#   inflating: train/train/99417.pkl
#   inflating: train/train/99418.pkl
#   inflating: train/train/99419.pkl
#   inflating: train/train/9942.pkl
#   inflating: train/train/99420.pkl
#   inflating: train/train/99421.pkl
#   inflating: train/train/99422.pkl
#   inflating: train/train/99423.pkl
#   inflating: train/train/99424.pkl
#   inflating: train/train/99425.pkl
#   inflating: train/train/99426.pkl
#   inflating: train/train/99427.pkl
#   inflating: train/train/99428.pkl
#   inflating: train/train/99429.pkl
#   inflating: train/train/9943.pkl
#   inflating: train/train/99430.pkl
#   inflating: train/train/99431.pkl
#   inflating: train/train/99432.pkl
#   inflating: train/train/99433.pkl
#   inflating: train/train/99434.pkl
#   inflating: train/train/99435.pkl
#   inflating: train/train/99436.pkl
#   inflating: train/train/99437.pkl
#   inflating: train/train/99438.pkl
#   inflating: train/train/99439.pkl
#   inflating: train/train/9944.pkl
#   inflating: train/train/99440.pkl
#   inflating: train/train/99441.pkl
#   inflating: train/train/99442.pkl
#   inflating: train/train/99443.pkl
#   inflating: train/train/99444.pkl
#   inflating: train/train/99445.pkl
#   inflating: train/train/99446.pkl
#   inflating: train/train/99447.pkl
#   inflating: train/train/99448.pkl
#   inflating: train/train/99449.pkl
#   inflating: train/train/9945.pkl
#   inflating: train/train/99450.pkl
#   inflating: train/train/99451.pkl
#   inflating: train/train/99452.pkl
#   inflating: train/train/99453.pkl
#   inflating: train/train/99454.pkl
#   inflating: train/train/99455.pkl
#   inflating: train/train/99456.pkl
#   inflating: train/train/99457.pkl
#   inflating: train/train/99458.pkl
#   inflating: train/train/99459.pkl
#   inflating: train/train/9946.pkl
#   inflating: train/train/99460.pkl
#   inflating: train/train/99461.pkl
#   inflating: train/train/99462.pkl
#   inflating: train/train/99463.pkl
#   inflating: train/train/99464.pkl
#   inflating: train/train/99465.pkl
#   inflating: train/train/99466.pkl
#   inflating: train/train/99467.pkl
#   inflating: train/train/99468.pkl
#   inflating: train/train/99469.pkl
#   inflating: train/train/9947.pkl
#   inflating: train/train/99470.pkl
#   inflating: train/train/99471.pkl
#   inflating: train/train/99472.pkl
#   inflating: train/train/99473.pkl
#   inflating: train/train/99474.pkl
#   inflating: train/train/99475.pkl
#   inflating: train/train/99476.pkl
#   inflating: train/train/99477.pkl
#   inflating: train/train/99478.pkl
#   inflating: train/train/99479.pkl
#   inflating: train/train/9948.pkl
#   inflating: train/train/99480.pkl
#   inflating: train/train/99481.pkl
#   inflating: train/train/99482.pkl
#   inflating: train/train/99483.pkl
#   inflating: train/train/99484.pkl
#   inflating: train/train/99485.pkl
#   inflating: train/train/99486.pkl
#   inflating: train/train/99487.pkl
#   inflating: train/train/99488.pkl
#   inflating: train/train/99489.pkl
#   inflating: train/train/9949.pkl
#   inflating: train/train/99490.pkl
#   inflating: train/train/99491.pkl
#   inflating: train/train/99492.pkl
#   inflating: train/train/99493.pkl
#   inflating: train/train/99494.pkl
#   inflating: train/train/99495.pkl
#   inflating: train/train/99496.pkl
#   inflating: train/train/99497.pkl
#   inflating: train/train/99498.pkl
#   inflating: train/train/99499.pkl
#   inflating: train/train/995.pkl
#   inflating: train/train/9950.pkl
#   inflating: train/train/99500.pkl
#   inflating: train/train/99501.pkl
#   inflating: train/train/99502.pkl
#   inflating: train/train/99503.pkl
#   inflating: train/train/99504.pkl
#   inflating: train/train/99505.pkl
#   inflating: train/train/99506.pkl
#   inflating: train/train/99507.pkl
#   inflating: train/train/99508.pkl
#   inflating: train/train/99509.pkl
#   inflating: train/train/9951.pkl
#   inflating: train/train/99510.pkl
#   inflating: train/train/99511.pkl
#   inflating: train/train/99512.pkl
# ...
#   inflating: val_in/val_in/5066.pkl
#   inflating: val_in/val_in/509.pkl
#   inflating: val_in/val_in/51.pkl
#   inflating: val_in/val_in/510.pkl
#   inflating: val_in/val_in/5122.pkl
#   inflating: val_in/val_in/5123.pkl
#   inflating: val_in/val_in/5136.pkl
#   inflating: val_in/val_in/5145.pkl
#   inflating: val_in/val_in/5147.pkl
#   inflating: val_in/val_in/5148.pkl
#   inflating: val_in/val_in/5166.pkl
#   inflating: val_in/val_in/5170.pkl
#   inflating: val_in/val_in/5171.pkl
#   inflating: val_in/val_in/5188.pkl
#   inflating: val_in/val_in/5249.pkl
#   inflating: val_in/val_in/525.pkl
#   inflating: val_in/val_in/5269.pkl
#   inflating: val_in/val_in/5272.pkl
#   inflating: val_in/val_in/5298.pkl
#   inflating: val_in/val_in/5316.pkl
#   inflating: val_in/val_in/5321.pkl
#   inflating: val_in/val_in/5324.pkl
#   inflating: val_in/val_in/5335.pkl
#   inflating: val_in/val_in/5344.pkl
#   inflating: val_in/val_in/5345.pkl
#   inflating: val_in/val_in/5366.pkl
#   inflating: val_in/val_in/5368.pkl
#   inflating: val_in/val_in/5373.pkl
#   inflating: val_in/val_in/5398.pkl
#   inflating: val_in/val_in/5409.pkl
#   inflating: val_in/val_in/5412.pkl
#   inflating: val_in/val_in/5448.pkl
#   inflating: val_in/val_in/5477.pkl
#   inflating: val_in/val_in/5479.pkl
#   inflating: val_in/val_in/5497.pkl
#   inflating: val_in/val_in/5505.pkl
#   inflating: val_in/val_in/5514.pkl
#   inflating: val_in/val_in/5524.pkl
#   inflating: val_in/val_in/5531.pkl
#   inflating: val_in/val_in/5535.pkl
#   inflating: val_in/val_in/5552.pkl
#   inflating: val_in/val_in/5566.pkl
#   inflating: val_in/val_in/5581.pkl
#   inflating: val_in/val_in/5590.pkl
#   inflating: val_in/val_in/56.pkl
#   inflating: val_in/val_in/5600.pkl
#   inflating: val_in/val_in/5609.pkl
#   inflating: val_in/val_in/5613.pkl
#   inflating: val_in/val_in/5642.pkl
#   inflating: val_in/val_in/5657.pkl
#   inflating: val_in/val_in/5668.pkl
#   inflating: val_in/val_in/5693.pkl
#   inflating: val_in/val_in/5700.pkl
#   inflating: val_in/val_in/5734.pkl
#   inflating: val_in/val_in/5744.pkl
#   inflating: val_in/val_in/5751.pkl
#   inflating: val_in/val_in/5759.pkl
#   inflating: val_in/val_in/5775.pkl
#   inflating: val_in/val_in/5787.pkl
#   inflating: val_in/val_in/5819.pkl
#   inflating: val_in/val_in/583.pkl
#   inflating: val_in/val_in/5834.pkl
#   inflating: val_in/val_in/5848.pkl
#   inflating: val_in/val_in/585.pkl
#   inflating: val_in/val_in/5851.pkl
#   inflating: val_in/val_in/5853.pkl
#   inflating: val_in/val_in/5864.pkl
#   inflating: val_in/val_in/5874.pkl
#   inflating: val_in/val_in/5884.pkl
#   inflating: val_in/val_in/5898.pkl
#   inflating: val_in/val_in/59.pkl
#   inflating: val_in/val_in/5905.pkl
#   inflating: val_in/val_in/5908.pkl
#   inflating: val_in/val_in/5909.pkl
#   inflating: val_in/val_in/5913.pkl
#   inflating: val_in/val_in/592.pkl
#   inflating: val_in/val_in/5921.pkl
#   inflating: val_in/val_in/5929.pkl
#   inflating: val_in/val_in/5932.pkl
#   inflating: val_in/val_in/5933.pkl
#   inflating: val_in/val_in/5936.pkl
#   inflating: val_in/val_in/595.pkl
#   inflating: val_in/val_in/5961.pkl
#   inflating: val_in/val_in/5965.pkl
#   inflating: val_in/val_in/5972.pkl
#   inflating: val_in/val_in/6001.pkl
#   inflating: val_in/val_in/6011.pkl
#   inflating: val_in/val_in/6017.pkl
#   inflating: val_in/val_in/6028.pkl
#   inflating: val_in/val_in/6035.pkl
#   inflating: val_in/val_in/6045.pkl
#   inflating: val_in/val_in/6049.pkl
#   inflating: val_in/val_in/6051.pkl
#   inflating: val_in/val_in/606.pkl
#   inflating: val_in/val_in/6061.pkl
#   inflating: val_in/val_in/6072.pkl
#   inflating: val_in/val_in/612.pkl
#   inflating: val_in/val_in/6135.pkl
#   inflating: val_in/val_in/6167.pkl
#   inflating: val_in/val_in/6168.pkl
#   inflating: val_in/val_in/6170.pkl
#   inflating: val_in/val_in/6181.pkl
#   inflating: val_in/val_in/62.pkl
#   inflating: val_in/val_in/623.pkl
#   inflating: val_in/val_in/6238.pkl
#   inflating: val_in/val_in/625.pkl
#   inflating: val_in/val_in/6254.pkl
#   inflating: val_in/val_in/6261.pkl
#   inflating: val_in/val_in/6272.pkl
#   inflating: val_in/val_in/6279.pkl
#   inflating: val_in/val_in/6280.pkl
#   inflating: val_in/val_in/6291.pkl
#   inflating: val_in/val_in/6297.pkl
#   inflating: val_in/val_in/6311.pkl
#   inflating: val_in/val_in/6333.pkl
#   inflating: val_in/val_in/6335.pkl
#   inflating: val_in/val_in/634.pkl
#   inflating: val_in/val_in/6348.pkl
#   inflating: val_in/val_in/636.pkl
#   inflating: val_in/val_in/6369.pkl
#   inflating: val_in/val_in/6372.pkl
#   inflating: val_in/val_in/6405.pkl
#   inflating: val_in/val_in/6411.pkl
#   inflating: val_in/val_in/6420.pkl
#   inflating: val_in/val_in/6428.pkl
#   inflating: val_in/val_in/6445.pkl
#   inflating: val_in/val_in/6457.pkl
#   inflating: val_in/val_in/6467.pkl
#   inflating: val_in/val_in/6471.pkl
#   inflating: val_in/val_in/6477.pkl
#   inflating: val_in/val_in/6478.pkl
#   inflating: val_in/val_in/6479.pkl
#   inflating: val_in/val_in/6487.pkl
#   inflating: val_in/val_in/6511.pkl
#   inflating: val_in/val_in/6513.pkl
#   inflating: val_in/val_in/6525.pkl
#   inflating: val_in/val_in/6531.pkl
#   inflating: val_in/val_in/6542.pkl
#   inflating: val_in/val_in/6550.pkl
#   inflating: val_in/val_in/6558.pkl
#   inflating: val_in/val_in/6574.pkl
#   inflating: val_in/val_in/659.pkl
#   inflating: val_in/val_in/662.pkl
#   inflating: val_in/val_in/6629.pkl
#   inflating: val_in/val_in/663.pkl
#   inflating: val_in/val_in/6634.pkl
#   inflating: val_in/val_in/6668.pkl
#   inflating: val_in/val_in/6675.pkl
#   inflating: val_in/val_in/6704.pkl
#   inflating: val_in/val_in/6713.pkl
#   inflating: val_in/val_in/6736.pkl
#   inflating: val_in/val_in/6741.pkl
#   inflating: val_in/val_in/6745.pkl
#   inflating: val_in/val_in/6753.pkl
#   inflating: val_in/val_in/6763.pkl
#   inflating: val_in/val_in/6785.pkl
#   inflating: val_in/val_in/6806.pkl
#   inflating: val_in/val_in/681.pkl
#   inflating: val_in/val_in/6828.pkl
#   inflating: val_in/val_in/6837.pkl
#   inflating: val_in/val_in/6855.pkl
#   inflating: val_in/val_in/6857.pkl
#   inflating: val_in/val_in/6888.pkl
#   inflating: val_in/val_in/6889.pkl
#   inflating: val_in/val_in/6893.pkl
#   inflating: val_in/val_in/6894.pkl
#   inflating: val_in/val_in/692.pkl
#   inflating: val_in/val_in/6926.pkl
#   inflating: val_in/val_in/6961.pkl
#   inflating: val_in/val_in/6962.pkl
#   inflating: val_in/val_in/6964.pkl
#   inflating: val_in/val_in/6975.pkl
#   inflating: val_in/val_in/6979.pkl
#   inflating: val_in/val_in/7000.pkl
#   inflating: val_in/val_in/7011.pkl
#   inflating: val_in/val_in/7020.pkl
#   inflating: val_in/val_in/7040.pkl
#   inflating: val_in/val_in/7043.pkl
#   inflating: val_in/val_in/7049.pkl
#   inflating: val_in/val_in/7053.pkl
#   inflating: val_in/val_in/7054.pkl
#   inflating: val_in/val_in/7068.pkl
#   inflating: val_in/val_in/7074.pkl
#   inflating: val_in/val_in/710.pkl
#   inflating: val_in/val_in/7123.pkl
#   inflating: val_in/val_in/7141.pkl
#   inflating: val_in/val_in/7157.pkl
#   inflating: val_in/val_in/7166.pkl
#   inflating: val_in/val_in/7167.pkl
#   inflating: val_in/val_in/7172.pkl
#   inflating: val_in/val_in/7178.pkl
#   inflating: val_in/val_in/7206.pkl
#   inflating: val_in/val_in/7212.pkl
#   inflating: val_in/val_in/7227.pkl
#   inflating: val_in/val_in/7240.pkl
#   inflating: val_in/val_in/7248.pkl
#   inflating: val_in/val_in/7263.pkl
#   inflating: val_in/val_in/7273.pkl
#   inflating: val_in/val_in/7305.pkl
#   inflating: val_in/val_in/731.pkl
#   inflating: val_in/val_in/7328.pkl
#   inflating: val_in/val_in/7330.pkl
#   inflating: val_in/val_in/7348.pkl
#   inflating: val_in/val_in/735.pkl
#   inflating: val_in/val_in/7353.pkl
#   inflating: val_in/val_in/738.pkl
#   inflating: val_in/val_in/7415.pkl
#   inflating: val_in/val_in/7417.pkl
#   inflating: val_in/val_in/7457.pkl
#   inflating: val_in/val_in/7465.pkl
#   inflating: val_in/val_in/7479.pkl
#   inflating: val_in/val_in/7482.pkl
#   inflating: val_in/val_in/7495.pkl
#   inflating: val_in/val_in/7509.pkl
#   inflating: val_in/val_in/7513.pkl
#   inflating: val_in/val_in/7526.pkl
#   inflating: val_in/val_in/7538.pkl
#   inflating: val_in/val_in/7540.pkl
#   inflating: val_in/val_in/7544.pkl
#   inflating: val_in/val_in/7563.pkl
#   inflating: val_in/val_in/7564.pkl
#   inflating: val_in/val_in/7566.pkl
#   inflating: val_in/val_in/7575.pkl
#   inflating: val_in/val_in/7590.pkl
#   inflating: val_in/val_in/7601.pkl
#   inflating: val_in/val_in/7615.pkl
#   inflating: val_in/val_in/7633.pkl
#   inflating: val_in/val_in/764.pkl
#   inflating: val_in/val_in/7643.pkl
#   inflating: val_in/val_in/7660.pkl
#   inflating: val_in/val_in/7696.pkl
#   inflating: val_in/val_in/7700.pkl
#   inflating: val_in/val_in/7701.pkl
#   inflating: val_in/val_in/7703.pkl
#   inflating: val_in/val_in/7717.pkl
#   inflating: val_in/val_in/7726.pkl
#   inflating: val_in/val_in/773.pkl
#   inflating: val_in/val_in/7733.pkl
#   inflating: val_in/val_in/7743.pkl
#   inflating: val_in/val_in/7753.pkl
#   inflating: val_in/val_in/7764.pkl
#   inflating: val_in/val_in/7766.pkl
#   inflating: val_in/val_in/7784.pkl
#   inflating: val_in/val_in/7805.pkl
#   inflating: val_in/val_in/7807.pkl
#   inflating: val_in/val_in/7849.pkl
#   inflating: val_in/val_in/786.pkl
#   inflating: val_in/val_in/788.pkl
#   inflating: val_in/val_in/7889.pkl
#   inflating: val_in/val_in/7899.pkl
#   inflating: val_in/val_in/7925.pkl
#   inflating: val_in/val_in/7928.pkl
#   inflating: val_in/val_in/7946.pkl
#   inflating: val_in/val_in/7971.pkl
#   inflating: val_in/val_in/7993.pkl
#   inflating: val_in/val_in/8012.pkl
#   inflating: val_in/val_in/8026.pkl
#   inflating: val_in/val_in/8057.pkl
#   inflating: val_in/val_in/8058.pkl
#   inflating: val_in/val_in/8061.pkl
#   inflating: val_in/val_in/8065.pkl
#   inflating: val_in/val_in/8073.pkl
#   inflating: val_in/val_in/8079.pkl
#   inflating: val_in/val_in/810.pkl
#   inflating: val_in/val_in/8112.pkl
#   inflating: val_in/val_in/813.pkl
#   inflating: val_in/val_in/816.pkl
#   inflating: val_in/val_in/8165.pkl
#   inflating: val_in/val_in/8176.pkl
#   inflating: val_in/val_in/8188.pkl
#   inflating: val_in/val_in/8209.pkl
#   inflating: val_in/val_in/8217.pkl
#   inflating: val_in/val_in/8226.pkl
#   inflating: val_in/val_in/8267.pkl
#   inflating: val_in/val_in/8272.pkl
#   inflating: val_in/val_in/8291.pkl
#   inflating: val_in/val_in/8292.pkl
#   inflating: val_in/val_in/8303.pkl
#   inflating: val_in/val_in/8307.pkl
#   inflating: val_in/val_in/8310.pkl
#   inflating: val_in/val_in/8317.pkl
#   inflating: val_in/val_in/8324.pkl
#   inflating: val_in/val_in/8340.pkl
#   inflating: val_in/val_in/8345.pkl
#   inflating: val_in/val_in/8350.pkl
#   inflating: val_in/val_in/8363.pkl
#   inflating: val_in/val_in/8364.pkl
#   inflating: val_in/val_in/8373.pkl
#   inflating: val_in/val_in/8387.pkl
#   inflating: val_in/val_in/8435.pkl
#   inflating: val_in/val_in/8449.pkl
#   inflating: val_in/val_in/8477.pkl
#   inflating: val_in/val_in/8482.pkl
#   inflating: val_in/val_in/8490.pkl
#   inflating: val_in/val_in/8491.pkl
#   inflating: val_in/val_in/8502.pkl
#   inflating: val_in/val_in/8503.pkl
#   inflating: val_in/val_in/8507.pkl
#   inflating: val_in/val_in/8510.pkl
#   inflating: val_in/val_in/8514.pkl
#   inflating: val_in/val_in/8524.pkl
#   inflating: val_in/val_in/8546.pkl
#   inflating: val_in/val_in/8565.pkl
#   inflating: val_in/val_in/859.pkl
#   inflating: val_in/val_in/8620.pkl
#   inflating: val_in/val_in/8664.pkl
#   inflating: val_in/val_in/8681.pkl
#   inflating: val_in/val_in/8687.pkl
#   inflating: val_in/val_in/8689.pkl
#   inflating: val_in/val_in/8692.pkl
#   inflating: val_in/val_in/8726.pkl
#   inflating: val_in/val_in/8727.pkl
#   inflating: val_in/val_in/8736.pkl
#   inflating: val_in/val_in/8741.pkl
#   inflating: val_in/val_in/8746.pkl
#   inflating: val_in/val_in/8748.pkl
#   inflating: val_in/val_in/8750.pkl
#   inflating: val_in/val_in/8756.pkl
#   inflating: val_in/val_in/8772.pkl
#   inflating: val_in/val_in/8776.pkl
#   inflating: val_in/val_in/8782.pkl
#   inflating: val_in/val_in/8783.pkl
#   inflating: val_in/val_in/8787.pkl
#   inflating: val_in/val_in/8808.pkl
#   inflating: val_in/val_in/881.pkl
#   inflating: val_in/val_in/8816.pkl
#   inflating: val_in/val_in/8818.pkl
#   inflating: val_in/val_in/8822.pkl
#   inflating: val_in/val_in/8826.pkl
#   inflating: val_in/val_in/8857.pkl
#   inflating: val_in/val_in/8867.pkl
#   inflating: val_in/val_in/8879.pkl
#   inflating: val_in/val_in/8901.pkl
#   inflating: val_in/val_in/892.pkl
#   inflating: val_in/val_in/8930.pkl
#   inflating: val_in/val_in/8963.pkl
#   inflating: val_in/val_in/8970.pkl
#   inflating: val_in/val_in/8971.pkl
#   inflating: val_in/val_in/8983.pkl
#   inflating: val_in/val_in/8987.pkl
#   inflating: val_in/val_in/900.pkl
#   inflating: val_in/val_in/9006.pkl
#   inflating: val_in/val_in/9008.pkl
#   inflating: val_in/val_in/9016.pkl
#   inflating: val_in/val_in/9043.pkl
#   inflating: val_in/val_in/9065.pkl
#   inflating: val_in/val_in/9066.pkl
#   inflating: val_in/val_in/9068.pkl
#   inflating: val_in/val_in/9070.pkl
#   inflating: val_in/val_in/9071.pkl
#   inflating: val_in/val_in/9076.pkl
#   inflating: val_in/val_in/908.pkl
#   inflating: val_in/val_in/9086.pkl
#   inflating: val_in/val_in/9096.pkl
#   inflating: val_in/val_in/9099.pkl
#   inflating: val_in/val_in/9101.pkl
#   inflating: val_in/val_in/9129.pkl
#   inflating: val_in/val_in/9156.pkl
#   inflating: val_in/val_in/9208.pkl
#   inflating: val_in/val_in/9216.pkl
#   inflating: val_in/val_in/924.pkl
#   inflating: val_in/val_in/9252.pkl
#   inflating: val_in/val_in/9254.pkl
#   inflating: val_in/val_in/9260.pkl
#   inflating: val_in/val_in/9262.pkl
#   inflating: val_in/val_in/9269.pkl
#   inflating: val_in/val_in/932.pkl
#   inflating: val_in/val_in/9325.pkl
#   inflating: val_in/val_in/9337.pkl
#   inflating: val_in/val_in/9355.pkl
#   inflating: val_in/val_in/9384.pkl
#   inflating: val_in/val_in/9398.pkl
#   inflating: val_in/val_in/9402.pkl
#   inflating: val_in/val_in/9418.pkl
#   inflating: val_in/val_in/942.pkl
#   inflating: val_in/val_in/9428.pkl
#   inflating: val_in/val_in/943.pkl
#   inflating: val_in/val_in/9434.pkl
#   inflating: val_in/val_in/9455.pkl
#   inflating: val_in/val_in/9467.pkl
#   inflating: val_in/val_in/9481.pkl
#   inflating: val_in/val_in/9514.pkl
#   inflating: val_in/val_in/9528.pkl
#   inflating: val_in/val_in/9532.pkl
#   inflating: val_in/val_in/9568.pkl
#   inflating: val_in/val_in/9574.pkl
#   inflating: val_in/val_in/9582.pkl
#   inflating: val_in/val_in/9596.pkl
#   inflating: val_in/val_in/9616.pkl
#   inflating: val_in/val_in/9633.pkl
#   inflating: val_in/val_in/965.pkl
#   inflating: val_in/val_in/9664.pkl
#   inflating: val_in/val_in/9671.pkl
#   inflating: val_in/val_in/9674.pkl
#   inflating: val_in/val_in/9678.pkl
#   inflating: val_in/val_in/968.pkl
#   inflating: val_in/val_in/9689.pkl
#   inflating: val_in/val_in/9707.pkl
#   inflating: val_in/val_in/9721.pkl
#   inflating: val_in/val_in/9731.pkl
#   inflating: val_in/val_in/9741.pkl
#   inflating: val_in/val_in/9751.pkl
#   inflating: val_in/val_in/9752.pkl
#   inflating: val_in/val_in/9758.pkl
#   inflating: val_in/val_in/9765.pkl
#   inflating: val_in/val_in/9768.pkl
#   inflating: val_in/val_in/977.pkl
#   inflating: val_in/val_in/9780.pkl
#   inflating: val_in/val_in/9796.pkl
#   inflating: val_in/val_in/9797.pkl
#   inflating: val_in/val_in/9836.pkl
#   inflating: val_in/val_in/9838.pkl
#   inflating: val_in/val_in/984.pkl
#   inflating: val_in/val_in/9844.pkl
#   inflating: val_in/val_in/9849.pkl
#   inflating: val_in/val_in/9864.pkl
#   inflating: val_in/val_in/9897.pkl
#   inflating: val_in/val_in/99.pkl
#   inflating: val_in/val_in/9905.pkl
#   inflating: val_in/val_in/9910.pkl
#   inflating: val_in/val_in/9918.pkl

# %%
# !cp ./drive/MyDrive/CSE251B/weights.w ./

# %% [markdown]
# ### model

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os, os.path
import numpy
import pickle
from glob import glob

"""
 This notebook uses train as an example.
 Change to the val folder for evaluation
"""

new_path = "./train/train"

# number of sequences in each dataset
# train:205942  val:3200 test: 36272
# sequences sampled at 10HZ rate

class ArgoverseDataset(Dataset):
    """Dataset class for Argoverse"""
    def __init__(self, data_path: str, transform=None):
        super(ArgoverseDataset, self).__init__()
        self.data_path = data_path
        self.transform = transform

        self.pkl_list = glob(os.path.join(self.data_path, '*'))
        self.pkl_list.sort()

    def __len__(self):
        return len(self.pkl_list)

    def __getitem__(self, idx):

        pkl_path = self.pkl_list[idx]
        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

        if self.transform:
            data = self.transform(data)

        return data


# intialize a dataset
data  = ArgoverseDataset(data_path=new_path)

# %%
def my_collate(batch):
    """ collate lists of samples into batches, create [ batch_sz x agent_sz x seq_len x feature] """
    inp = [numpy.dstack([scene['p_in'], scene['v_in']]) for scene in batch]
    out = [numpy.dstack([scene['p_out'], scene['v_out']]) for scene in batch]

    inp = torch.LongTensor(inp).to(device)
    out = torch.LongTensor(out).to(device)
    return [inp, out]

# %%
batch_sz = 128

def my_collate(batch):
    """ collate lists of samples into batches, create [ batch_sz x agent_sz x seq_len x feature] """
    valid_x = []
    valid_y = []
    for scene in batch:

        mask = scene['car_mask']
        inp = numpy.dstack([scene['p_in'], scene['v_in']])
        out = numpy.dstack([scene['p_out'], scene['v_out']])
        #print(out.shape)
        for j in range(len(mask)):
          if mask[j][0]==1:
            valid_x.append(inp[j])
            valid_y.append(out[j])
        '''
        inp = numpy.stack( inp, axis=0 )
        out = [numpy.dstack([scene['p_out'], scene['v_out']]) for scene in batch]
        out = numpy.stack( out, axis=0 )
        '''
    inp = torch.LongTensor(valid_x).to(device)
    out = torch.LongTensor(valid_y).to(device)
    return [inp, out]

#train_loader = DataLoader(val_dataset,batch_size=batch_sz, shuffle = False, collate_fn=my_collate, num_workers=0)

#split_number = int(len(data)*0.8)
import random
#train_idx = [i for i in range(split_number)]
train_idx = random.sample([i for i in range(0,len(data))],int(0.8*len(data)))
test_idx = list(set([i for i in range(0,len(data))])-set(train_idx))
#test_idx = [i+split_number for i in range(len(data)-split_number)]
train_sub = torch.utils.data.Subset(data, train_idx)
test_sub = torch.utils.data.Subset(data, test_idx)

train_dataset = DataLoader(train_sub,batch_size=batch_sz, shuffle = False, collate_fn=my_collate, num_workers=0)
test_dataset = DataLoader(test_sub,batch_size=batch_sz, shuffle = False, collate_fn=my_collate, num_workers=0)

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 1288
# 322

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %%
import matplotlib.pyplot as plt
import random

class CNNClassifier(nn.Module):
    def __init__(self):
        super(CNNClassifier, self).__init__()
        self.conv1_px = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_py = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_vx = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_vy = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        '''
        self.conv2_px = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_py = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_vx = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_vy = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')

        self.conv4_px = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv4_py = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv4_vx = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv4_vy = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        '''
        self.conv3_px = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv3_py = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv3_vx = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv3_vy = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')

        self.activation = nn.Sigmoid()
        #self.activation = nn.ReLU()

        #self.avgpool = torch.nn.AvgPool2d((2,1))
        #self.embedding = torch.nn.Embedding(num_embeddings = 65000, embedding_dim = 64)
        #self.lstm = torch.nn.LSTM(input_size = 1, hidden_size = 6*30*4, num_layers = 1,
        #                            batch_first = True, dropout = 0.2)
        #self.decoder = torch.nn.Conv2d(60,60,1)
        #self.decoder2 = torch.nn.AvgPool2d((9,1))
        self.lstm = torch.nn.LSTM(input_size = 4, hidden_size = 64, num_layers = 2, batch_first = True, dropout = 0.2)

        self.dense1 = nn.Linear(64, 32)
        self.dense2 = nn.Linear(32, 4)
        # as we have 5 classes
        #self.linear = nn.Linear(8*2*512, 5) # last dimension
    def forward(self, x):
        px,py,vx,vy=x
        px = self.activation(self.conv1_px(px))
        py = self.activation(self.conv1_py(py))
        vx = self.activation(self.conv1_vx(vx))
        vy = self.activation(self.conv1_vy(vy))
        '''
        px = self.activation(self.conv2_px(px))
        py = self.activation(self.conv2_py(py))
        vx = self.activation(self.conv2_vx(vx))
        vy = self.activation(self.conv2_vy(vy))

        px = self.activation(self.conv4_px(px))
        py = self.activation(self.conv4_py(py))
        vx = self.activation(self.conv4_vx(vx))
        vy = self.activation(self.conv4_vy(vy))
        '''
        px = self.activation(self.conv3_px(px))
        py = self.activation(self.conv3_py(py))
        vx = self.activation(self.conv3_vx(vx))
        vy = self.activation(self.conv3_vy(vy))

        x = torch.cat((px,py,vx,vy), 1)
        x = torch.permute(x,(0,2,1))

        x,_ = self.lstm(x)
        # return-sequence = false
        x = x[:, -1, :]

        #x = torch.flatten(x,1)
        #x = self.conv2(x)
        #x = self.activation(self.dense1(x))
        x = self.dense1(x)
        x = self.dense2(x)


        return x

# create our model

lstm = CNNClassifier()
lstm.to(device)
# Out:
# CNNClassifier(
#   (conv1_px): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_py): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vx): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vy): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_px): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_py): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vx): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (activation): Sigmoid()
#   (lstm): LSTM(4, 64, num_layers=2, batch_first=True, dropout=0.2)
#   (dense1): Linear(in_features=64, out_features=32, bias=True)
#   (dense2): Linear(in_features=32, out_features=4, bias=True)
# )

# %% [markdown]
# ## v3 different normalization

# %%
num_epochs = 200
learning_rate = 0.0005

#input_size = 4
#hidden_size = 2
num_layers = 2

num_classes = 1

#lstm = nn.LSTM(input_size=(19,4), hidden_size=128, num_layers=2, proj_size=(30,4))

criterion = torch.nn.MSELoss().to(device)    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)
train_loss_overall = []
val_loss_overall = []
global_min = 99999999
# Train the model
for epoch in range(num_epochs):
    for i_batch, sample_batch in enumerate(train_dataset):
        trainX, trainY = sample_batch


        #trainX = torch.reshape(trainX,(trainX.shape[0]*trainX.shape[1], trainX.shape[2], trainX.shape[3]))
        trainX = trainX.float()

        #trainY = torch.reshape(trainY,(trainY.shape[0]*trainY.shape[1], trainY.shape[2], trainY.shape[3]))
        trainY = trainY.float()

        xy = trainX[:,:,0:2]

        start = xy[:,0:1,:]
        start_repeat = start.repeat((1,19,1))
        # align xy to 0,0 start
        xy = xy-start_repeat
        #rotate so the final orientation is pointing towards positive x axis
        displacement = xy[:,18:19,:] - xy[:,0:1,:]
        # tan = oppo/adj
        angle = torch.atan2(displacement[:,:,1],displacement[:,:,0])
        #angle = torch.squeeze(angle)


        rotation_matrix = torch.cat((torch.hstack((torch.cos(angle),-torch.sin(angle)))[:,:,None],torch.hstack((torch.sin(angle),torch.cos(angle)))[:,:,None]),dim=2)

        translated = torch.matmul(xy,rotation_matrix)
        #print(translated.shape)




        # preprocess data
        px = translated[:,:,0]
        px = px[:,None,:]

        py = translated[:,:,1]
        py = py[:,None,:]

        vx = trainX[:,:,2]
        vx = vx[:,None,:]

        vy = trainX[:,:,3]
        vy = vy[:,None,:]

        #print(px.shape)
        outputs = lstm([px,py,vx,vy])
        optimizer.zero_grad()


        #print(trainY.shape)
        #print(trainY[:,:,0:1,:].shape)
        # obtain the loss function
        #mean_recover = torch.stack((mean_px[:,0],mean_py[:,0],mean_vx[:,0],mean_vy[:,0]))
        #std_recover = torch.stack((std_px[:,0],std_py[:,0],std_vx[:,0],std_vy[:,0]))

        #print(std_recover.shape)
        #print(outputs.shape)
        #outputs = torch.mul(outputs,std_recover.T) + mean_recover.T


        outputs_xy = outputs[:,None,:2]
        outputs_recover = torch.matmul(outputs_xy,-1.0*rotation_matrix)+start

        #outputs = torch.hstack((torch.squeeze(outputs_recover),outputs[:,2:4]))


        #print(trainY.shape)
        #loss = criterion(outputs, trainY[:,0,:])
        loss = criterion(torch.squeeze(outputs_recover), trainY[:,0,:2])

        loss.backward()

        optimizer.step()
        if i_batch %1000==0:
            print(i_batch)
    if epoch % 1 == 0:
      print("Epoch: %d, training loss: %1.5f" % (epoch, loss.item()))
      total=0
      with torch.no_grad():
          mean_squared_error = nn.MSELoss().to(device)
          for i_batch, sample_batch in enumerate(test_dataset):
              testX, testY = sample_batch
              testX = testX.float().to(device)
              #print(testX.is_cuda)
              testY = testY.float().to(device)
              # preprocess data
              xy = testX[:,:,0:2]

              start = xy[:,0:1,:]
              start_repeat = start.repeat((1,19,1))
              # align xy to 0,0 start
              xy = xy-start_repeat
              #rotate so the final orientation is pointing towards positive x axis
              displacement = xy[:,18:19,:] - xy[:,0:1,:]
              # tan = oppo/adj
              angle = torch.atan2(displacement[:,:,1],displacement[:,:,0])
              #angle = torch.squeeze(angle)


              rotation_matrix = torch.cat((torch.hstack((torch.cos(angle),-torch.sin(angle)))[:,:,None],torch.hstack((torch.sin(angle),torch.cos(angle)))[:,:,None]),dim=2)

              translated = torch.matmul(xy,rotation_matrix)

              px = translated[:,:,0]
              px = px[:,None,:]

              py = translated[:,:,1]
              py = py[:,None,:]

              vx = testX[:,:,2]
              vx = vx[:,None,:]

              vy = testX[:,:,3]
              vy = vy[:,None,:]
              # calculate outputs by running images through the network
              outputs = lstm([px,py,vx,vy])

              #std_recover = torch.stack((std_px[:,0],std_py[:,0],std_vx[:,0],std_vy[:,0]))
              #outputs = torch.mul(outputs,std_recover.T) + mean_recover.T
              outputs_xy = outputs[:,None,:2]
              outputs_recover = torch.matmul(outputs_xy,-1.0*rotation_matrix)+start

              #outputs = torch.hstack((torch.squeeze(outputs_recover),outputs[:,2:4]))
              #print(outputs.is_cuda)
              #print(outputs.shape)
              #mse = mean_squared_error(outputs,testY[:,0,:])
              mse = mean_squared_error(torch.squeeze(outputs_recover),testY[:,0,:2])
              #print(testY[:,:,0:1,:].shape)
              #print(mse)
              total += mse
          print("Epoch: %d, val loss: %1.5f" % (epoch, total/(i_batch+1)))
    train_loss_overall.append(loss.item())
    val_loss_overall.append(total/(i_batch+1))
    if total/(i_batch+1) < global_min:
      global_min = total/(i_batch+1)
      torch.save(lstm.state_dict(), "./weights_CNN.w")
# Out:
# 0
# 1000
# Epoch: 0, training loss: 0.14756
# Epoch: 0, val loss: 0.19267
# 0
# 1000
# Epoch: 1, training loss: 0.15653
# Epoch: 1, val loss: 0.18542
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-05378fea2005> in <cell line: 19>()
#      18 # Train the model
#      19 for epoch in range(num_epochs):
# ---> 20     for i_batch, sample_batch in enumerate(train_dataset):
#      21         trainX, trainY = sample_batch
#      22
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     631                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632                 self._reset()  # type: ignore[call-arg]
# --> 633             data = self._next_data()
#     634             self._num_yielded += 1
#     635             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     675     def _next_data(self):
#     676         index = self._next_index()  # may raise StopIteration
# --> 677         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678         if self._pin_memory:
#     679             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     296         if isinstance(idx, list):
#     297             return self.dataset[[self.indices[i] for i in idx]]
# --> 298         return self.dataset[self.indices[idx]]
#     299
#     300     def __len__(self):
#
# <ipython-input-75-cd703e4230b4> in __getitem__(self, idx)
#      34         pkl_path = self.pkl_list[idx]
#      35         with open(pkl_path, 'rb') as f:
# ---> 36             data = pickle.load(f)
#      37
#      38         if self.transform:
#
# KeyboardInterrupt:

# %%
lstm = CNNClassifier()
lstm.to(device)
lstm.load_state_dict(torch.load("./weights_CNN.w"))
lstm.eval()
# Out:
# CNNClassifier(
#   (conv1_px): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_py): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vx): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vy): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_px): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_py): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_vx): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_vy): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_px): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_py): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vx): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (activation): ReLU()
#   (lstm): LSTM(4, 64, num_layers=2, batch_first=True)
#   (dense1): Linear(in_features=64, out_features=64, bias=True)
#   (dense2): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss_overall)
plt.plot(val_loss_overall)
plt.show()

# %% [markdown]
# ## v4: 30 frames

# %%
import matplotlib.pyplot as plt
import random

class CNNClassifier(nn.Module):
    def __init__(self):
        super(CNNClassifier, self).__init__()
        self.conv1_px = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_py = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_vx = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_vy = nn.Conv1d(1, 16, 5,padding=(0,2),padding_mode='replicate')
        '''
        self.conv2_px = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_py = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_vx = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_vy = nn.Conv1d(16, 32, 5,padding=(0,2),padding_mode='replicate')

        self.conv4_px = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv4_py = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv4_vx = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv4_vy = nn.Conv1d(32, 16, 5,padding=(0,2),padding_mode='replicate')
        '''
        self.conv3_px = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv3_py = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv3_vx = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv3_vy = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')


        self.conv1_pxy = nn.Conv1d(2, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_vxy = nn.Conv1d(2, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_pvx = nn.Conv1d(2, 16, 5,padding=(0,2),padding_mode='replicate')
        self.conv1_pvy = nn.Conv1d(2, 16, 5,padding=(0,2),padding_mode='replicate')

        self.conv2_pxy = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_vxy = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_pvx = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')
        self.conv2_pvy = nn.Conv1d(16, 1, 5,padding=(0,2),padding_mode='replicate')

        #self.activation = nn.Sigmoid()
        self.activation = nn.ReLU()

        #self.avgpool = torch.nn.AvgPool2d((2,1))
        #self.embedding = torch.nn.Embedding(num_embeddings = 65000, embedding_dim = 64)
        #self.lstm = torch.nn.LSTM(input_size = 1, hidden_size = 6*30*4, num_layers = 1,
        #                            batch_first = True, dropout = 0.2)
        #self.decoder = torch.nn.Conv2d(60,60,1)
        #self.decoder2 = torch.nn.AvgPool2d((9,1))
        self.lstm = torch.nn.LSTM(input_size = 8, hidden_size = 512, num_layers = 2, batch_first = True, dropout = 0.2)

        self.dense1 = nn.Linear(512, 256)
        self.dense2 = nn.Linear(256, 120)
        # as we have 5 classes
        #self.linear = nn.Linear(8*2*512, 5) # last dimension
    def forward(self, x):
        px,py,vx,vy=x
        px = self.activation(self.conv1_px(px))
        py = self.activation(self.conv1_py(py))
        vx = self.activation(self.conv1_vx(vx))
        vy = self.activation(self.conv1_vy(vy))
        '''
        px = self.activation(self.conv2_px(px))
        py = self.activation(self.conv2_py(py))
        vx = self.activation(self.conv2_vx(vx))
        vy = self.activation(self.conv2_vy(vy))

        px = self.activation(self.conv4_px(px))
        py = self.activation(self.conv4_py(py))
        vx = self.activation(self.conv4_vx(vx))
        vy = self.activation(self.conv4_vy(vy))
        '''
        px = self.activation(self.conv3_px(px))
        py = self.activation(self.conv3_py(py))
        vx = self.activation(self.conv3_vx(vx))
        vy = self.activation(self.conv3_vy(vy))


        pxy = torch.cat((px,py), 1)
        vxy = torch.cat((vx,vy), 1)


        pvx = torch.cat((px,vx), 1)
        pvy = torch.cat((py,vy), 1)

        pxy = self.activation(self.conv1_pxy(pxy))
        vxy = self.activation(self.conv1_vxy(vxy))
        pvx = self.activation(self.conv1_pvx(pvx))
        pvy = self.activation(self.conv1_pvy(pvy))

        pxy = self.activation(self.conv2_pxy(pxy))
        vxy = self.activation(self.conv2_vxy(vxy))
        pvx = self.activation(self.conv2_pvx(pvx))
        pvy = self.activation(self.conv2_pvy(pvy))

        x = torch.cat((px,py,vx,vy,pxy,vxy,pvx,pvy), 1)
        x = torch.permute(x,(0,2,1))

        x,_ = self.lstm(x)
        # return-sequence = false
        x = x[:, -1, :]

        #x = torch.flatten(x,1)
        #x = self.conv2(x)
        #x = self.activation(self.dense1(x))
        x = self.dense1(x)
        x = self.dense2(x)
        x = x.reshape((x.size()[0],30,4))

        return x

# create our model

lstm = CNNClassifier()
lstm.to(device)
# Out:
# CNNClassifier(
#   (conv1_px): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_py): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vx): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vy): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_px): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_py): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vx): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_pxy): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vxy): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_pvx): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_pvy): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_pxy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_vxy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_pvx): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_pvy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (activation): ReLU()
#   (lstm): LSTM(8, 512, num_layers=2, batch_first=True, dropout=0.2)
#   (dense1): Linear(in_features=512, out_features=256, bias=True)
#   (dense2): Linear(in_features=256, out_features=120, bias=True)
# )

# %%
num_epochs = 200
learning_rate = 0.001

#input_size = 4
#hidden_size = 2
num_layers = 2

num_classes = 1

#lstm = nn.LSTM(input_size=(19,4), hidden_size=128, num_layers=2, proj_size=(30,4))

criterion = torch.nn.MSELoss().to(device)    # mean-squared error for regression
#optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)
train_loss_overall = []
val_loss_overall = []
global_min = 99999999
# Train the model
for epoch in range(num_epochs):
    for i_batch, sample_batch in enumerate(train_dataset):
        trainX, trainY = sample_batch


        #trainX = torch.reshape(trainX,(trainX.shape[0]*trainX.shape[1], trainX.shape[2], trainX.shape[3]))
        trainX = trainX.float()

        #trainY = torch.reshape(trainY,(trainY.shape[0]*trainY.shape[1], trainY.shape[2], trainY.shape[3]))
        trainY = trainY.float()

        xy = trainX[:,:,0:2]

        start = xy[:,0:1,:]
        start_repeat = start.repeat((1,19,1))
        # align xy to 0,0 start
        xy = xy-start_repeat
        #rotate so the final orientation is pointing towards positive x axis
        displacement = xy[:,18:19,:] - xy[:,0:1,:]
        # tan = oppo/adj
        angle = torch.atan2(displacement[:,:,1],displacement[:,:,0])
        #angle = torch.squeeze(angle)


        rotation_matrix = torch.cat((torch.hstack((torch.cos(angle),-torch.sin(angle)))[:,:,None],torch.hstack((torch.sin(angle),torch.cos(angle)))[:,:,None]),dim=2)

        translated = torch.matmul(xy,rotation_matrix)
        #print(translated.shape)




        # preprocess data
        px = translated[:,:,0]
        px = px[:,None,:]

        py = translated[:,:,1]
        py = py[:,None,:]

        vx = trainX[:,:,2]
        vx = vx[:,None,:]

        vy = trainX[:,:,3]
        vy = vy[:,None,:]

        #print(px.shape)
        outputs = lstm([px,py,vx,vy])
        optimizer.zero_grad()


        #print(trainY.shape)
        #print(trainY[:,:,0:1,:].shape)
        # obtain the loss function
        #mean_recover = torch.stack((mean_px[:,0],mean_py[:,0],mean_vx[:,0],mean_vy[:,0]))
        #std_recover = torch.stack((std_px[:,0],std_py[:,0],std_vx[:,0],std_vy[:,0]))

        #print(std_recover.shape)
        #print(outputs.shape)
        #outputs = torch.mul(outputs,std_recover.T) + mean_recover.T


        outputs_xy = outputs[:,:,:2]
        outputs_recover = torch.matmul(outputs_xy,-1.0*rotation_matrix)+start.repeat((1,30,1))

        #outputs = torch.hstack((torch.squeeze(outputs_recover),outputs[:,2:4]))


        #print(trainY.shape)
        #loss = criterion(outputs, trainY[:,0,:])
        loss = criterion(torch.squeeze(outputs_recover), trainY[:,:,:2])

        loss.backward()

        optimizer.step()
        if i_batch %1000==0:
            print(i_batch)
    if epoch % 1 == 0:
      print("Epoch: %d, training loss: %1.5f" % (epoch, loss.item()))
      total=0
      with torch.no_grad():
          mean_squared_error = nn.MSELoss().to(device)
          for i_batch, sample_batch in enumerate(test_dataset):
              testX, testY = sample_batch
              testX = testX.float().to(device)
              #print(testX.is_cuda)
              testY = testY.float().to(device)
              # preprocess data
              xy = testX[:,:,0:2]

              start = xy[:,0:1,:]
              start_repeat = start.repeat((1,19,1))
              # align xy to 0,0 start
              xy = xy-start_repeat
              #rotate so the final orientation is pointing towards positive x axis
              displacement = xy[:,18:19,:] - xy[:,0:1,:]
              # tan = oppo/adj
              angle = torch.atan2(displacement[:,:,1],displacement[:,:,0])
              #angle = torch.squeeze(angle)


              rotation_matrix = torch.cat((torch.hstack((torch.cos(angle),-torch.sin(angle)))[:,:,None],torch.hstack((torch.sin(angle),torch.cos(angle)))[:,:,None]),dim=2)

              translated = torch.matmul(xy,rotation_matrix)

              px = translated[:,:,0]
              px = px[:,None,:]

              py = translated[:,:,1]
              py = py[:,None,:]

              vx = testX[:,:,2]
              vx = vx[:,None,:]

              vy = testX[:,:,3]
              vy = vy[:,None,:]
              # calculate outputs by running images through the network
              outputs = lstm([px,py,vx,vy])

              #std_recover = torch.stack((std_px[:,0],std_py[:,0],std_vx[:,0],std_vy[:,0]))
              #outputs = torch.mul(outputs,std_recover.T) + mean_recover.T
              outputs_xy = outputs[:,:,:2]
              outputs_recover = torch.matmul(outputs_xy,-1.0*rotation_matrix)+start.repeat((1,30,1))

              #outputs = torch.hstack((torch.squeeze(outputs_recover),outputs[:,2:4]))
              #print(outputs.is_cuda)
              #print(outputs.shape)
              #mse = mean_squared_error(outputs,testY[:,0,:])
              mse = mean_squared_error(outputs_recover,testY[:,:,:2])
              #print(testY[:,:,0:1,:].shape)
              #print(mse)
              total += mse
          print("Epoch: %d, val loss: %1.5f" % (epoch, total/(i_batch+1)))
    train_loss_overall.append(loss.item())
    val_loss_overall.append(total/(i_batch+1))
    if total/(i_batch+1) < global_min:
      global_min = total/(i_batch+1)
      torch.save(lstm.state_dict(), "./weights_CNN4.w")
# Out:
# 0
# 1000
# Epoch: 0, training loss: 70.09001
# Epoch: 0, val loss: 74.42181
# 0
# 1000
# Epoch: 1, training loss: 54.52803
# Epoch: 1, val loss: 49.19555
# 0
# 1000
# Epoch: 2, training loss: 33.64244
# Epoch: 2, val loss: 32.30909
# 0
# 1000
# Epoch: 3, training loss: 5.98168
# Epoch: 3, val loss: 9.32161
# 0
# 1000
# Epoch: 4, training loss: 5.79849
# Epoch: 4, val loss: 8.73672
# 0
# 1000
# Epoch: 5, training loss: 2.87450
# Epoch: 5, val loss: 6.58233
# 0
# 1000
# Epoch: 6, training loss: 3.77294
# Epoch: 6, val loss: 5.49670
# 0
# 1000
# Epoch: 7, training loss: 3.97154
# Epoch: 7, val loss: 6.05871
# 0
# 1000
# Epoch: 8, training loss: 2.74613
# Epoch: 8, val loss: 6.22543
# 0
# 1000
# Epoch: 9, training loss: 3.18183
# Epoch: 9, val loss: 5.56047
# 0
# 1000
# Epoch: 10, training loss: 3.03072
# Epoch: 10, val loss: 5.65461
# 0
# 1000
# Epoch: 11, training loss: 2.67165
# Epoch: 11, val loss: 5.43748
# 0
# 1000
# Epoch: 12, training loss: 2.62707
# Epoch: 12, val loss: 4.96822
# 0
# 1000
# Epoch: 13, training loss: 2.68478
# Epoch: 13, val loss: 5.03742
# 0
# 1000
# Epoch: 14, training loss: 2.51240
# Epoch: 14, val loss: 4.89097
# 0
# 1000
# Epoch: 15, training loss: 2.49126
# Epoch: 15, val loss: 4.87477
# 0
# 1000
# Epoch: 16, training loss: 2.53098
# Epoch: 16, val loss: 5.03679
# 0
# 1000
# Epoch: 17, training loss: 2.56659
# Epoch: 17, val loss: 4.91418
# 0
# 1000
# Epoch: 18, training loss: 2.56809
# Epoch: 18, val loss: 4.75529
# 0
# 1000
# Epoch: 19, training loss: 2.52769
# Epoch: 19, val loss: 4.73775
# 0
# 1000
# Epoch: 20, training loss: 2.47427
# Epoch: 20, val loss: 4.77744
# 0
# 1000
# Epoch: 21, training loss: 2.47800
# Epoch: 21, val loss: 4.66470
# 0
# 1000
# Epoch: 22, training loss: 2.39972
# Epoch: 22, val loss: 4.53082
# 0
# 1000
# Epoch: 23, training loss: 2.58407
# Epoch: 23, val loss: 4.50857
# 0
# 1000
# Epoch: 24, training loss: 2.30948
# Epoch: 24, val loss: 4.50961
# 0
# 1000
# Epoch: 25, training loss: 2.47304
# Epoch: 25, val loss: 4.54281
# 0
# 1000
# Epoch: 26, training loss: 2.40303
# Epoch: 26, val loss: 4.50907
# 0
# 1000
# Epoch: 27, training loss: 2.34811
# Epoch: 27, val loss: 4.44850
# 0
# 1000
# Epoch: 28, training loss: 2.25666
# Epoch: 28, val loss: 4.38333
# 0
# 1000
# Epoch: 29, training loss: 2.23724
# Epoch: 29, val loss: 4.35557
# 0
# 1000
# Epoch: 30, training loss: 2.25537
# Epoch: 30, val loss: 4.39075
# 0
# 1000
# Epoch: 31, training loss: 2.28795
# Epoch: 31, val loss: 4.32494
# 0
# 1000
# Epoch: 32, training loss: 2.22014
# Epoch: 32, val loss: 4.33510
# 0
# 1000
# Epoch: 33, training loss: 2.23733
# Epoch: 33, val loss: 4.26399
# 0
# 1000
# Epoch: 34, training loss: 2.15401
# Epoch: 34, val loss: 4.26728
# 0
# 1000
# Epoch: 35, training loss: 2.20934
# Epoch: 35, val loss: 4.30755
# 0
# 1000
# Epoch: 36, training loss: 2.08253
# Epoch: 36, val loss: 4.25040
# 0
# 1000
# Epoch: 37, training loss: 2.15450
# Epoch: 37, val loss: 4.25601
# 0
# 1000
# Epoch: 38, training loss: 2.12322
# Epoch: 38, val loss: 4.28045
# 0
# 1000
# Epoch: 39, training loss: 2.11523
# Epoch: 39, val loss: 4.27796
# 0
# 1000
# Epoch: 40, training loss: 2.06961
# Epoch: 40, val loss: 4.17901
# 0
# 1000
# Epoch: 41, training loss: 2.03548
# Epoch: 41, val loss: 4.23205
# 0
# 1000
# Epoch: 42, training loss: 2.16631
# Epoch: 42, val loss: 4.26402
# 0
# 1000
# Epoch: 43, training loss: 2.04803
# Epoch: 43, val loss: 4.25101
# 0
# 1000
# Epoch: 44, training loss: 2.03766
# Epoch: 44, val loss: 4.19082
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-bd9418c5a4f2> in <cell line: 19>()
#      18 # Train the model
#      19 for epoch in range(num_epochs):
# ---> 20     for i_batch, sample_batch in enumerate(train_dataset):
#      21         trainX, trainY = sample_batch
#      22
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     631                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632                 self._reset()  # type: ignore[call-arg]
# --> 633             data = self._next_data()
#     634             self._num_yielded += 1
#     635             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     675     def _next_data(self):
#     676         index = self._next_index()  # may raise StopIteration
# --> 677         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678         if self._pin_memory:
#     679             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
# ---> 54         return self.collate_fn(data)
#
# <ipython-input-77-dfb4d6552e7c> in my_collate(batch)
#      21         '''
#      22     inp = torch.LongTensor(valid_x).to(device)
# ---> 23     out = torch.LongTensor(valid_y).to(device)
#      24     return [inp, out]
#      25
#
# KeyboardInterrupt:

# %%
PATH = "modelv4.pt"


torch.save({
            'model_state_dict': lstm.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            }, PATH)

# %%
# !cp ./modelv4.pt ./drive/MyDrive/CSE251B/

# %%
'''
model = Net()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

checkpoint = torch.load(PATH)
lstm.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])


model.eval()
# - or -
model.train()
'''

# %%
lstm = CNNClassifier()
lstm.to(device)
lstm.load_state_dict(torch.load("./weights_CNN4.w"))
lstm.eval()
# Out:
# CNNClassifier(
#   (conv1_px): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_py): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vx): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vy): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_px): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_py): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vx): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_pxy): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vxy): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_pvx): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_pvy): Conv1d(2, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_pxy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_vxy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_pvx): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_pvy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (activation): ReLU()
#   (lstm): LSTM(8, 512, num_layers=2, batch_first=True, dropout=0.2)
#   (dense1): Linear(in_features=512, out_features=256, bias=True)
#   (dense2): Linear(in_features=256, out_features=120, bias=True)
# )

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss_overall)
plt.plot([i.detach().cpu().numpy() for i in val_loss_overall])
plt.legend(['training','validation'])
plt.show()

# %% [markdown]
# ## v1 and v2

# %%
num_epochs = 200
learning_rate = 0.005

#input_size = 4
#hidden_size = 2
num_layers = 2

num_classes = 1

#lstm = nn.LSTM(input_size=(19,4), hidden_size=128, num_layers=2, proj_size=(30,4))

criterion = torch.nn.MSELoss().to(device)    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)
train_loss_overall = []
val_loss_overall = []
global_min = 99999999
# Train the model
for epoch in range(num_epochs):
    for i_batch, sample_batch in enumerate(train_dataset):
        trainX, trainY = sample_batch


        #trainX = torch.reshape(trainX,(trainX.shape[0]*trainX.shape[1], trainX.shape[2], trainX.shape[3]))
        trainX = trainX.float()

        #trainY = torch.reshape(trainY,(trainY.shape[0]*trainY.shape[1], trainY.shape[2], trainY.shape[3]))
        trainY = trainY.float()
        # preprocess data
        px = trainX[:,:,0]
        mean_px = torch.mean(px,dim=1).repeat((19,1)).T
        #std_px = torch.std(px,dim=1).repeat((19,1)).T
        #std_px = (torch.amax(px,dim=1)-torch.amin(px,dim=1)).repeat((19,1)).T

        px = (px-mean_px)
        px = px[:,None,:]

        py = trainX[:,:,1]
        mean_py = torch.mean(py,dim=1).repeat((19,1)).T
        #std_py = (torch.amax(py,dim=1)-torch.amin(py,dim=1)).repeat((19,1)).T
        py = (py-mean_py)
        py = py[:,None,:]

        vx = trainX[:,:,2]
        mean_vx = torch.mean(vx,dim=1).repeat((19,1)).T
        #std_vx = (torch.amax(vx,dim=1)-torch.amin(vx,dim=1)).repeat((19,1)).T
        vx = (vx-mean_vx)
        vx = vx[:,None,:]

        vy = trainX[:,:,3]
        mean_vy = torch.mean(vy,dim=1).repeat((19,1)).T
        #std_vy = (torch.amax(vy,dim=1)-torch.amin(vy,dim=1)).repeat((19,1)).T
        vy = (vy-mean_vy)
        vy = vy[:,None,:]

        #print(px.shape)
        outputs = lstm([px,py,vx,vy])
        optimizer.zero_grad()


        #print(trainY.shape)
        #print(trainY[:,:,0:1,:].shape)
        # obtain the loss function
        mean_recover = torch.stack((mean_px[:,0],mean_py[:,0],mean_vx[:,0],mean_vy[:,0]))
        #std_recover = torch.stack((std_px[:,0],std_py[:,0],std_vx[:,0],std_vy[:,0]))

        #print(std_recover.shape)
        #print(outputs.shape)
        #outputs = torch.mul(outputs,std_recover.T) + mean_recover.T
        outputs = outputs + mean_recover.T

        #print(trainY.shape)
        loss = criterion(outputs, trainY[:,0,:])

        loss.backward()

        optimizer.step()
        if i_batch %1000==0:
            print(i_batch)
    if epoch % 1 == 0:
      print("Epoch: %d, training loss: %1.5f" % (epoch, loss.item()))
      total=0
      with torch.no_grad():
          mean_squared_error = nn.MSELoss().to(device)
          for i_batch, sample_batch in enumerate(test_dataset):
              testX, testY = sample_batch
              testX = testX.float().to(device)
              #print(testX.is_cuda)
              testY = testY.float().to(device)
              # preprocess data
              px = testX[:,:,0]
              mean_px = torch.mean(px,dim=1).repeat((19,1)).T
              #std_px = (torch.amax(px,dim=1)-torch.amin(px,dim=1)).repeat((19,1)).T
              px = (px-mean_px)
              px = px[:,None,:]

              py = testX[:,:,1]
              mean_py = torch.mean(py,dim=1).repeat((19,1)).T
              #std_py = (torch.amax(py,dim=1)-torch.amin(py,dim=1)).repeat((19,1)).T
              py = (py-mean_py)
              py = py[:,None,:]

              vx = testX[:,:,2]
              mean_vx = torch.mean(vx,dim=1).repeat((19,1)).T
              #std_vx = (torch.amax(vx,dim=1)-torch.amin(vx,dim=1)).repeat((19,1)).T
              vx = (vx-mean_vx)
              vx = vx[:,None,:]

              vy = testX[:,:,3]
              mean_vy = torch.mean(vy,dim=1).repeat((19,1)).T
              #std_vy = (torch.amax(vy,dim=1)-torch.amin(vy,dim=1)).repeat((19,1)).T
              vy = (vy-mean_vy)
              vy = vy[:,None,:]
              # calculate outputs by running images through the network
              outputs = lstm([px,py,vx,vy])
              mean_recover = torch.stack((mean_px[:,0],mean_py[:,0],mean_vx[:,0],mean_vy[:,0]))
              #std_recover = torch.stack((std_px[:,0],std_py[:,0],std_vx[:,0],std_vy[:,0]))
              #outputs = torch.mul(outputs,std_recover.T) + mean_recover.T
              outputs = outputs + mean_recover.T
              #print(outputs.is_cuda)
              #print(outputs.shape)
              mse = mean_squared_error(outputs,testY[:,0,:])
              #print(testY[:,:,0:1,:].shape)
              #print(mse)
              total += mse
          print("Epoch: %d, val loss: %1.5f" % (epoch, total/(i_batch+1)))
    train_loss_overall.append(loss.item())
    val_loss_overall.append(total/(i_batch+1))
    if total/(i_batch+1) < global_min:
      global_min = total/(i_batch+1)
      torch.save(lstm.state_dict(), "./weights_CNN.w")
# Out:
# 0
# 1000
# Epoch: 0, training loss: 3.31204
# Epoch: 0, val loss: 2.66394
# 0
# 1000
# Epoch: 1, training loss: 3.23665
# Epoch: 1, val loss: 2.54386
# 0
# 1000
# Epoch: 2, training loss: 3.34062
# Epoch: 2, val loss: 2.53746
# 0
# 1000
# Epoch: 3, training loss: 3.54924
# Epoch: 3, val loss: 2.54233
# 0
# 1000
# Epoch: 4, training loss: 3.23882
# Epoch: 4, val loss: 2.49882
# 0
# 1000
# Epoch: 5, training loss: 3.32696
# Epoch: 5, val loss: 2.49356
# 0
# 1000
# Epoch: 6, training loss: 3.15842
# Epoch: 6, val loss: 2.51088
# 0
# 1000
# Epoch: 7, training loss: 3.31350
# Epoch: 7, val loss: 2.50617
# 0
# 1000
# Epoch: 8, training loss: 3.17348
# Epoch: 8, val loss: 2.48967
# 0
# 1000
# Epoch: 9, training loss: 3.10131
# Epoch: 9, val loss: 2.50372
# 0
# 1000
# Epoch: 10, training loss: 3.16356
# Epoch: 10, val loss: 2.50051
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-55595b061998> in <cell line: 19>()
#      18 # Train the model
#      19 for epoch in range(num_epochs):
# ---> 20     for i_batch, sample_batch in enumerate(train_dataset):
#      21         trainX, trainY = sample_batch
#      22
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     631                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632                 self._reset()  # type: ignore[call-arg]
# --> 633             data = self._next_data()
#     634             self._num_yielded += 1
#     635             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     675     def _next_data(self):
#     676         index = self._next_index()  # may raise StopIteration
# --> 677         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678         if self._pin_memory:
#     679             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     296         if isinstance(idx, list):
#     297             return self.dataset[[self.indices[i] for i in idx]]
# --> 298         return self.dataset[self.indices[idx]]
#     299
#     300     def __len__(self):
#
# <ipython-input-73-cd703e4230b4> in __getitem__(self, idx)
#      34         pkl_path = self.pkl_list[idx]
#      35         with open(pkl_path, 'rb') as f:
# ---> 36             data = pickle.load(f)
#      37
#      38         if self.transform:
#
# KeyboardInterrupt:

# %%
lstm = CNNClassifier()
lstm.to(device)
lstm.load_state_dict(torch.load("./weights_CNN.w"))
lstm.eval()
# Out:
# CNNClassifier(
#   (conv1_px): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_py): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vx): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv1_vy): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_px): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_py): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_vx): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv2_vy): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_px): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_py): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vx): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (conv3_vy): Conv1d(16, 1, kernel_size=(5,), stride=(1,), padding=(0, 2), padding_mode=replicate)
#   (activation): ReLU()
#   (lstm): LSTM(4, 64, num_layers=2, batch_first=True)
#   (dense1): Linear(in_features=64, out_features=64, bias=True)
#   (dense2): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
mean_squared_error = nn.MSELoss().to(device)
total = 0
'''
for i_batch, sample_batch in enumerate(test_dataset):
    trainX, trainY = sample_batch


    #trainX = torch.reshape(trainX,(trainX.shape[0]*trainX.shape[1], trainX.shape[2], trainX.shape[3]))
    trainX = trainX.float().to(device)

    #trainY = torch.reshape(trainY,(trainY.shape[0]*trainY.shape[1], trainY.shape[2], trainY.shape[3]))
    trainY = trainY.float().to(device)
'''

with torch.no_grad():
    for i_batch, sample_batch in enumerate(test_dataset):
        testX, testY = sample_batch
        testX = testX.float().to(device)
        #print(testX.is_cuda)
        testY = testY.float().to(device)
        # calculate outputs by running images through the network
        outputs = lstm(testX)
        #print(outputs.is_cuda)
        #print(outputs.shape)
        mse = mean_squared_error(outputs,testY[:,:,0:1,:])
        #print(testY[:,:,0:1,:].shape)
        #print(mse)
        total += mse

        if i_batch %100==0:
            print(i_batch)
# Out:
# 0
# 100
# 200
# 300

# %%
total/(i_batch+1)
# Out:
# tensor(183.4635, device='cuda:0')

# %% [markdown]
# ## prediction

# %%
data_test  = ArgoverseDataset(data_path='val_in/val_in')

# %%
np.where(data_test[0]['track_id']==data_test[0]['agent_id'])[0][0]
# Out:
# 3

# %%
def my_collate_test(scene):
    """ collate lists of samples into batches, create [ batch_sz x agent_sz x seq_len x feature] """
    inp = numpy.dstack([scene['p_in'], scene['v_in']])
    #out = [numpy.dstack([scene['p_out'], scene['v_out']]) for scene in batch]

    inp = torch.LongTensor(inp).to(device)
    #out = torch.LongTensor(out).to(device)
    return inp

# %%
import csv
import copy

# %%
f1 = open('./sample_submission.csv', newline='')
f = open('./sample_submission1.csv', 'w')
reader = csv.reader(f1)
writer = csv.writer(f)
row1 = next(reader)  # gets the first line
writer.writerow(row1)
f1.close()




with torch.no_grad():
  for i in range(len(data_test)):
    all_data = torch.zeros([60,19+30,4],dtype=torch.float).to(device)
    all_data[:,:19,:] = my_collate_test(data_test[i])
    assert all_data.shape == (60,19+30,4)
    #testX = my_collate_test([data_test[i]])
    id = np.where(data_test[i]['track_id']==data_test[i]['agent_id'])[0][0]
    all_data = all_data[id:id+1]
    assert all_data.shape == (1,19+30,4)
    data_to_csv = []
    #for j in range(30):
    #testX = testX.float().to(device)
    #print(testX.shape)
    with torch.no_grad():
        testX = all_data[0:1,j:j+19,:]
        #print(testX.is_cuda)
        testY = testY.float().to(device)
        # preprocess data
        xy = testX[:,:,0:2]

        start = xy[:,0:1,:]
        start_repeat = start.repeat((1,19,1))
        # align xy to 0,0 start
        xy = xy-start_repeat
        #rotate so the final orientation is pointing towards positive x axis
        displacement = xy[:,18:19,:] - xy[:,0:1,:]
        # tan = oppo/adj
        angle = torch.atan2(displacement[:,:,1],displacement[:,:,0])
        #angle = torch.squeeze(angle)


        rotation_matrix = torch.cat((torch.hstack((torch.cos(angle),-torch.sin(angle)))[:,:,None],torch.hstack((torch.sin(angle),torch.cos(angle)))[:,:,None]),dim=2)

        translated = torch.matmul(xy,rotation_matrix)

        px = translated[:,:,0]
        px = px[:,None,:]

        py = translated[:,:,1]
        py = py[:,None,:]

        vx = testX[:,:,2]
        vx = vx[:,None,:]

        vy = testX[:,:,3]
        vy = vy[:,None,:]
        # calculate outputs by running images through the network
        outputs = lstm([px,py,vx,vy])
        outputs_xy = outputs[:,None,:2]
        outputs_recover = torch.matmul(outputs_xy,-1.0*rotation_matrix)+start

        outputs = torch.hstack((torch.squeeze(outputs_recover)[None,:],outputs[:,2:4]))
      #print(outputs.shape)
    all_data[0,j+19:j+20,:]=outputs[0,:]
    outputs = torch.squeeze(outputs[0,:2])
    #print(outputs.shape)
    data_to_csv.append(float(outputs[0].cpu().numpy()))
    data_to_csv.append(float(outputs[1].cpu().numpy()))
    #break
    #print(outputs.shape)
    #row = [data_test[i]['scene_idx']]+[(float(outputs[i,0].cpu().numpy()),float(outputs[i,1].cpu().numpy())) for i in range(len(outputs))]
    # open the file in the write mode
    # write a row to the csv file
    assert len(data_to_csv)==60
    row = [data_test[i]['scene_idx']]+data_to_csv
    writer.writerow(row)
    #break
# close the file
f.close()

# %% [markdown]
# ## v4 out

# %%
f1 = open('./sample_submission.csv', newline='')
f = open('./sample_submission1.csv', 'w')
reader = csv.reader(f1)
writer = csv.writer(f)
row1 = next(reader)  # gets the first line
writer.writerow(row1)
f1.close()




with torch.no_grad():
  for i in range(len(data_test)):
    all_data = torch.zeros([60,19+30,4],dtype=torch.float).to(device)
    all_data[:,:19,:] = my_collate_test(data_test[i])
    assert all_data.shape == (60,19+30,4)
    #testX = my_collate_test([data_test[i]])
    id = np.where(data_test[i]['track_id']==data_test[i]['agent_id'])[0][0]
    all_data = all_data[id:id+1]
    assert all_data.shape == (1,19+30,4)
    data_to_csv = []
    #for j in range(30):
    #testX = testX.float().to(device)
    #print(testX.shape)

    testX = all_data[0:1,0:19,:]
    #print(testX.is_cuda)
    testY = testY.float().to(device)
    # preprocess data
    xy = testX[:,:,0:2]

    start = xy[:,0:1,:]
    start_repeat = start.repeat((1,19,1))
    # align xy to 0,0 start
    xy = xy-start_repeat
    #rotate so the final orientation is pointing towards positive x axis
    displacement = xy[:,18:19,:] - xy[:,0:1,:]
    # tan = oppo/adj
    angle = torch.atan2(displacement[:,:,1],displacement[:,:,0])
    #angle = torch.squeeze(angle)


    rotation_matrix = torch.cat((torch.hstack((torch.cos(angle),-torch.sin(angle)))[:,:,None],torch.hstack((torch.sin(angle),torch.cos(angle)))[:,:,None]),dim=2)

    translated = torch.matmul(xy,rotation_matrix)

    px = translated[:,:,0]
    px = px[:,None,:]

    py = translated[:,:,1]
    py = py[:,None,:]

    vx = testX[:,:,2]
    vx = vx[:,None,:]

    vy = testX[:,:,3]
    vy = vy[:,None,:]
    # calculate outputs by running images through the network
    outputs = lstm([px,py,vx,vy])
    outputs_xy = outputs[:,:,:2]
    outputs_recover = torch.matmul(outputs_xy,-1.0*rotation_matrix)+start.repeat((1,30,1))

        #outputs = torch.hstack((torch.squeeze(outputs_recover)[None,:],outputs[:,2:4]))
      #print(outputs.shape)
      #all_data[0,j+19:j+20,:]=outputs[0,:]
      #outputs = torch.squeeze(outputs[0,:2])
      #print(outputs.shape)
    for j in range(30):
      data_to_csv.append(float(outputs_recover[0,j,0].cpu().numpy()))
      data_to_csv.append(float(outputs_recover[0,j,1].cpu().numpy()))
      #break
      #print(outputs.shape)
    #row = [data_test[i]['scene_idx']]+[(float(outputs[i,0].cpu().numpy()),float(outputs[i,1].cpu().numpy())) for i in range(len(outputs))]
    # open the file in the write mode
    # write a row to the csv file
    assert len(data_to_csv)==60
    row = [data_test[i]['scene_idx']]+data_to_csv
    writer.writerow(row)
    #break
# close the file
f.close()

# %% [markdown]
# ## saving

# %%
# !cp ./weights_CNN4.w ./drive/MyDrive/CSE251B/

# %%
# !mv ./weights_CNN.w ./weights_CNNv2.w
# !cp ./weights_CNNv2.w ./drive/MyDrive/CSE251B/

# %%
! cp ./sample_submission1.csv ./drive/MyDrive/CSE251B/
